# %% [markdown]
# # Consignes
#
# Intégrer le fichier USvideos.csv qui représente un ensemble de 8000 vidéos Youtube.
#
# Merger le fichier US_category_id.json pour récupérer le nom des catégories. Il conviendra de bien spécifier l'ID du document.
#
#
# # Questions
# - 1) Récupérer toutes les vidéos de la chaîne Apple.
# - 2) Compter le nombre de catégories différentes
# - 3) Si vous ne l'avez pas déjà fait, découper les tags en listes et mettre à jour les tags de chacun des documents avec une requête update.
# - 4) Récupérer les vidéos les plus vues.
# - 5) Compter le nombre moyen de vues en fonction de la catégorie.
# - 6) Récupérer les chaines Youtube avec la plus grande moyenne de likes.

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['youtube']

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'exercices', 'local', 'series']

# %%
from datetime import datetime
df_youtube = pd.read_csv("./data/USvideos.csv",parse_dates=['date'])
df_youtube['date']=df_youtube['date']+'.2020'
df_youtube['date']=df_youtube['date'].apply(lambda x:datetime.strptime(str(x),"%d.%M.%Y"))
df_youtube.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# 4  jacksfilms|parody|parodies|iphone|iphone x|iph...  1168130   96666
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
# 2     39774         170708  https://i.ytimg.com/vi/cLdxuaxaQwc/default.jpg
# 3      4542          12829  https://i.ytimg.com/vi/WYYvHb03Eog/default.jpg
# 4       568           6666  https://i.ytimg.com/vi/sjlHnJvXdQs/default.jpg
#
#                  date
# 0 2020-01-13 00:09:00
# 1 2020-01-13 00:09:00
# 2 2020-01-13 00:09:00
# 3 2020-01-13 00:09:00
# 4 2020-01-13 00:09:00

# %% [markdown]
# ## Question 0

# %%
import json
with open("./data/US_category_id.json") as readfile:
    data = json.load(readfile)
    
data= pd.json_normalize(data['items'])
data.head()
# Out:
#                     kind                                               etag  \
# 0  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/Xy1mB4_yLrHy_BmKm...
# 1  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/UZ1oLIIz2dxIhO45Z...
# 2  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/nqRIq97-xe5XRZTxb...
# 3  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/HwXKamM1Q20q9BN-o...
# 4  youtube#videoCategory  "m2yskBQFythfE4irbTIeOgYYfBU/9GQMSRjrZdHeb1OEM...
#
#    id         snippet.channelId     snippet.title  snippet.assignable
# 0   1  UCBR8-60-B28hp2BmDPdntcQ  Film & Animation                True
# 1   2  UCBR8-60-B28hp2BmDPdntcQ  Autos & Vehicles                True
# 2  10  UCBR8-60-B28hp2BmDPdntcQ             Music                True
# 3  15  UCBR8-60-B28hp2BmDPdntcQ    Pets & Animals                True
# 4  17  UCBR8-60-B28hp2BmDPdntcQ            Sports                True

# %%
data['id']=data['id'].astype(int)

# %%
df=df_youtube.join(data.set_index('id'), on='category_id')
df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# 4  jacksfilms|parody|parodies|iphone|iphone x|iph...  1168130   96666
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
# 2     39774         170708  https://i.ytimg.com/vi/cLdxuaxaQwc/default.jpg
# 3      4542          12829  https://i.ytimg.com/vi/WYYvHb03Eog/default.jpg
# 4       568           6666  https://i.ytimg.com/vi/sjlHnJvXdQs/default.jpg
#
#                  date                   kind  \
# 0 2020-01-13 00:09:00  youtube#videoCategory
# 1 2020-01-13 00:09:00  youtube#videoCategory
# 2 2020-01-13 00:09:00  youtube#videoCategory
# 3 2020-01-13 00:09:00  youtube#videoCategory
# 4 2020-01-13 00:09:00  youtube#videoCategory
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
#
#           snippet.channelId         snippet.title  snippet.assignable
# 0  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True
# 1  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
# 2  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True
# 3  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True
# 4  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True

# %% [markdown]
# ### Netoyer les données

# %%
df.isna().sum().sum()
# Out:
# 0

# %%
df.columns
# Out:
# Index(['video_id', 'title', 'channel_title', 'category_id', 'tags', 'views',
#        'likes', 'dislikes', 'comment_total', 'thumbnail_link', 'date', 'kind',
#        'etag', 'snippet_channelId', 'snippet_title', 'snippet_assignable'],
#       dtype='object')

# %%
df=df.rename(columns={"snippet.title":"snippet_title",'snippet.assignable':'snippet_assignable','snippet.channelId':'snippet_channelId'})

# %%
df['ID'] = df.index

# %%
df.head()
# Out:
#       video_id                                              title  \
# 0  XpVt6Z1Gjjo  1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED Y...
# 1  K4wEI5zhHB0            iPhone X — Introducing iPhone X — Apple
# 2  cLdxuaxaQwc                                        My Response
# 3  WYYvHb03Eog                          Apple iPhone X first look
# 4  sjlHnJvXdQs                                  iPhone X (parody)
#
#       channel_title  category_id  \
# 0  Logan Paul Vlogs           24
# 1             Apple           28
# 2         PewDiePie           22
# 3         The Verge           28
# 4        jacksfilms           23
#
#                                                 tags    views   likes  \
# 0  logan paul vlog|logan paul|logan|paul|olympics...  4394029  320053
# 1  Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lig...  7860119  185853
# 2                                             [none]  5845909  576597
# 3  apple iphone x hands on|Apple iPhone X|iPhone ...  2642103   24975
# 4  jacksfilms|parody|parodies|iphone|iphone x|iph...  1168130   96666
#
#    dislikes  comment_total                                  thumbnail_link  \
# 0      5931          46245  https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg
# 1     26679              0  https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg
# 2     39774         170708  https://i.ytimg.com/vi/cLdxuaxaQwc/default.jpg
# 3      4542          12829  https://i.ytimg.com/vi/WYYvHb03Eog/default.jpg
# 4       568           6666  https://i.ytimg.com/vi/sjlHnJvXdQs/default.jpg
#
#                  date                   kind  \
# 0 2020-01-13 00:09:00  youtube#videoCategory
# 1 2020-01-13 00:09:00  youtube#videoCategory
# 2 2020-01-13 00:09:00  youtube#videoCategory
# 3 2020-01-13 00:09:00  youtube#videoCategory
# 4 2020-01-13 00:09:00  youtube#videoCategory
#
#                                                 etag  \
# 0  "m2yskBQFythfE4irbTIeOgYYfBU/UVB9oxX2Bvqa_w_y3...
# 1  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
# 2  "m2yskBQFythfE4irbTIeOgYYfBU/xId8RX7vRN8rqkbYZ...
# 3  "m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBc...
# 4  "m2yskBQFythfE4irbTIeOgYYfBU/G9LHzQmx44rX2S5ya...
#
#           snippet_channelId         snippet_title  snippet_assignable  ID
# 0  UCBR8-60-B28hp2BmDPdntcQ         Entertainment                True   0
# 1  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True   1
# 2  UCBR8-60-B28hp2BmDPdntcQ        People & Blogs                True   2
# 3  UCBR8-60-B28hp2BmDPdntcQ  Science & Technology                True   3
# 4  UCBR8-60-B28hp2BmDPdntcQ                Comedy                True   4

# %% [markdown]
# ### Importer les données

# %%
def slice_generator(df, chunk_size=10):
    current_row = 0
    total_rows = df.shape[0]
    while current_row < total_rows:
        yield df[current_row:current_row + chunk_size]
        current_row += chunk_size

# %%
for df_chunk in slice_generator(df):
    records = df_chunk.to_dict(orient='records')
    collection.insert_many(records)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5fc2b31b3f42e014b17a1eb7'),
#  'video_id': 'XpVt6Z1Gjjo',
#  'title': '1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED YOUTUBE FOREVER!',
#  'channel_title': 'Logan Paul Vlogs',
#  'category_id': 24,
#  'tags': ['logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 l ...
#  'views': 4394029,
#  'likes': 320053,
#  'dislikes': 5931,
#  'comment_total': 46245,
#  'thumbnail_link': 'https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg',
#  'date': 13.09}

# %% [markdown]
# ## Question 1

# %%
list(collection.find({"channel_title":"Apple"}))
# Out:
# [{'_id': ObjectId('5fc2b31b3f42e014b17a1eb8'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': ['Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bionic,augmented reality,emoji,animoji,Face ID,Apple Pay,camera,smartphone,Apple,iPhone 10,iPhone Ten,iPhone,Portrait Lighting,A11 Bi ...
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('5fc35ac3f76d9cf67a9eff72'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f003c'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 12200526,
#   'likes': 258842,
#   'dislikes': 44339,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f0114'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 15731493,
#   'likes': 321403,
#   'dislikes': 57528,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 15.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f0213'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 18082737,
#   'likes': 359392,
#   'dislikes': 64933,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 16.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f02fa'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 17.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f0396'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': ['Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods roll ad,apple music skateboard ad,apple music train station ad,apple music roll ad,misbehaving,Apple,airpods,apple watch,apple watch series 3,apple watch cellular,apple watch 4g,apple music,40 million songs on your wrist,apple skateboard ad,apple train station ad,apple roll ad,apple watch skateboard ad,apple watch train station ad,apple watch roll ad,airpods skateboard ad,airpods train station ad,airpods rol ...
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 18.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f0483'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 19.09},
#  {'_id': ObjectId('5fc35ac4f76d9cf67a9f0573'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 20.09},
#  {'_id': ObjectId('5fc35ac5f76d9cf67a9f0f3d'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': ['Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect,The Shacks,Apple,new,iPhone,iPhone 8,iPhone 8 Plus,iOS 11,4.7-inch,5.5-inch,Portrait Lighting,Shot on iPhone,camera,iphonography,smartphone,This Strange Effect ...
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 3.1},
#  {'_id': ObjectId('5fc35ac5f76d9cf67a9f102e'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 4.1},
#  {'_id': ObjectId('5fc35ac5f76d9cf67a9f112c'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 5.1},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f1eaa'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f1f74'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 12200526,
#   'likes': 258842,
#   'dislikes': 44339,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f204c'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 15731493,
#   'likes': 321403,
#   'dislikes': 57528,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 15.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f214b'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 18082737,
#   'likes': 359392,
#   'dislikes': 64933,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 16.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f2232'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 17.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f22ce'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 18.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f23bb'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 19.09},
#  {'_id': ObjectId('5fc35b38f76d9cf67a9f24ab'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 20.09},
#  {'_id': ObjectId('5fc35b39f76d9cf67a9f2e75'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 3.1},
#  {'_id': ObjectId('5fc35b39f76d9cf67a9f2f66'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 4.1},
#  {'_id': ObjectId('5fc35b39f76d9cf67a9f3064'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 5.1},
#  {'_id': ObjectId('5fc361b7630cce3636113bd7'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('5fc361b7630cce3636113ca1'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 12200526,
#   'likes': 258842,
#   'dislikes': 44339,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09},
#  {'_id': ObjectId('5fc361b7630cce3636113d79'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 15731493,
#   'likes': 321403,
#   'dislikes': 57528,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 15.09},
#  {'_id': ObjectId('5fc361b7630cce3636113e78'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 18082737,
#   'likes': 359392,
#   'dislikes': 64933,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 16.09},
#  {'_id': ObjectId('5fc361b7630cce3636113f5f'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 17.09},
#  {'_id': ObjectId('5fc361b7630cce3636113ffb'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 18.09},
#  {'_id': ObjectId('5fc361b7630cce36361140e8'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 19.09},
#  {'_id': ObjectId('5fc361b7630cce36361141d8'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 20.09},
#  {'_id': ObjectId('5fc361b8630cce3636114ba2'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 3.1},
#  {'_id': ObjectId('5fc361b8630cce3636114c93'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 4.1},
#  {'_id': ObjectId('5fc361b8630cce3636114d91'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 5.1},
#  {'_id': ObjectId('5fc389433213d478c9a6f5e8'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09},
#  {'_id': ObjectId('5fc389443213d478c9a6f6b2'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 12200526,
#   'likes': 258842,
#   'dislikes': 44339,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09},
#  {'_id': ObjectId('5fc389443213d478c9a6f78a'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 15731493,
#   'likes': 321403,
#   'dislikes': 57528,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 15.09},
#  {'_id': ObjectId('5fc389443213d478c9a6f889'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 18082737,
#   'likes': 359392,
#   'dislikes': 64933,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 16.09},
#  {'_id': ObjectId('5fc389443213d478c9a6f970'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 17.09},
#  {'_id': ObjectId('5fc389443213d478c9a6fa0c'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 18.09},
#  {'_id': ObjectId('5fc389443213d478c9a6faf9'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 19.09},
#  {'_id': ObjectId('5fc389453213d478c9a6fbe9'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 20.09},
#  {'_id': ObjectId('5fc389463213d478c9a705b3'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 3.1},
#  {'_id': ObjectId('5fc389473213d478c9a706a4'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 4.1},
#  {'_id': ObjectId('5fc389473213d478c9a707a2'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 5.1},
#  {'_id': ObjectId('5fc3a37b73adfa6f7048c08f'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '7860119',
#   'likes': '185853',
#   'dislikes': '26679',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c159'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '12200526',
#   'likes': '258842',
#   'dislikes': '44339',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c231'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '15731493',
#   'likes': '321403',
#   'dislikes': '57528',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 15.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c330'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '18082737',
#   'likes': '359392',
#   'dislikes': '64933',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 16.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c417'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '19707391',
#   'likes': '381919',
#   'dislikes': '69465',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 17.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c4b3'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': '782543',
#   'likes': '14647',
#   'dislikes': '1489',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 18.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c5a0'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': '3987580',
#   'likes': '26021',
#   'dislikes': '8719',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 19.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37c73adfa6f7048c690'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': '4112187',
#   'likes': '26609',
#   'dislikes': '8982',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': 20.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37f73adfa6f7048d05a'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': '117564',
#   'likes': '1240',
#   'dislikes': '459',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 3.1,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37f73adfa6f7048d14b'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': '163024',
#   'likes': '1538',
#   'dislikes': '539',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 4.1,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3a37f73adfa6f7048d249'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': '183325',
#   'likes': '1700',
#   'dislikes': '570',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': 5.1,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3b5fa558170a507e09aab'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': '28',
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '7860119',
#   'likes': '185853',
#   'dislikes': '26679',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 13.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3b5fa558170a507e09b75'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': '28',
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '12200526',
#   'likes': '258842',
#   'dislikes': '44339',
#   'comment_total': '0',
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': 14.09,
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True},
#  {'_id': ObjectId('5fc3b5fa558170a507e09c4d'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': '28',
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': '15731493',
#   'likes': '321403',
# ...
#   'date': datetime.datetime(1900, 9, 16, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 674},
#  {'_id': ObjectId('5fc50c00f95a613d73ae7cc7'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(1900, 9, 17, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 905},
#  {'_id': ObjectId('5fc50c01f95a613d73ae7d63'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(1900, 9, 18, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1061},
#  {'_id': ObjectId('5fc50c01f95a613d73ae7e50'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(1900, 9, 19, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1298},
#  {'_id': ObjectId('5fc50c01f95a613d73ae7f40'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(1900, 9, 20, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1538},
#  {'_id': ObjectId('5fc50c03f95a613d73ae890a'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(1900, 10, 3, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4044},
#  {'_id': ObjectId('5fc50c03f95a613d73ae89fb'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(1900, 9, 4, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4285},
#  {'_id': ObjectId('5fc50c03f95a613d73ae8af9'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(1900, 9, 5, 0, 0),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4539},
#  {'_id': ObjectId('5fc51b0de75eb2eb3ec46388'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 7860119,
#   'likes': 185853,
#   'dislikes': 26679,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(2020, 1, 13, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1},
#  {'_id': ObjectId('5fc51b0de75eb2eb3ec46452'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 12200526,
#   'likes': 258842,
#   'dislikes': 44339,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(2020, 1, 14, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 203},
#  {'_id': ObjectId('5fc51b0ee75eb2eb3ec4652a'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 15731493,
#   'likes': 321403,
#   'dislikes': 57528,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(2020, 1, 15, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 419},
#  {'_id': ObjectId('5fc51b0ee75eb2eb3ec46629'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 18082737,
#   'likes': 359392,
#   'dislikes': 64933,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(2020, 1, 16, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 674},
#  {'_id': ObjectId('5fc51b0fe75eb2eb3ec46710'),
#   'video_id': 'K4wEI5zhHB0',
#   'title': 'iPhone X — Introducing iPhone X — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|iPhone 10|iPhone Ten|iPhone|Portrait Lighting|A11 Bionic|augmented reality|emoji|animoji|Face ID|Apple Pay|camera|smartphone',
#   'views': 19707391,
#   'likes': 381919,
#   'dislikes': 69465,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/K4wEI5zhHB0/default.jpg',
#   'date': datetime.datetime(2020, 1, 17, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 905},
#  {'_id': ObjectId('5fc51b0fe75eb2eb3ec467ac'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 782543,
#   'likes': 14647,
#   'dislikes': 1489,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(2020, 1, 18, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1061},
#  {'_id': ObjectId('5fc51b0fe75eb2eb3ec46899'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 3987580,
#   'likes': 26021,
#   'dislikes': 8719,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(2020, 1, 19, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1298},
#  {'_id': ObjectId('5fc51b10e75eb2eb3ec46989'),
#   'video_id': 'A9k88sMyiJM',
#   'title': 'Apple Watch Series 3 + Apple Music — Roll — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|airpods|apple watch|apple watch series 3|apple watch cellular|apple watch 4g|apple music|40 million songs on your wrist|apple skateboard ad|apple train station ad|apple roll ad|apple watch skateboard ad|apple watch train station ad|apple watch roll ad|airpods skateboard ad|airpods train station ad|airpods roll ad|apple music skateboard ad|apple music train station ad|apple music roll ad|misbehaving',
#   'views': 4112187,
#   'likes': 26609,
#   'dislikes': 8982,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/A9k88sMyiJM/default.jpg',
#   'date': datetime.datetime(2020, 1, 20, 0, 9),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 1538},
#  {'_id': ObjectId('5fc51b13e75eb2eb3ec47353'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 117564,
#   'likes': 1240,
#   'dislikes': 459,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(2020, 1, 3, 0, 1),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4044},
#  {'_id': ObjectId('5fc51b13e75eb2eb3ec47444'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 163024,
#   'likes': 1538,
#   'dislikes': 539,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(2020, 1, 4, 0, 1),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4285},
#  {'_id': ObjectId('5fc51b13e75eb2eb3ec47542'),
#   'video_id': 'REZl-ANYKKY',
#   'title': 'iPhone 8 Plus — Portraits of Her  — Apple',
#   'channel_title': 'Apple',
#   'category_id': 28,
#   'tags': 'Apple|new|iPhone|iPhone 8|iPhone 8 Plus|iOS 11|4.7-inch|5.5-inch|Portrait Lighting|Shot on iPhone|camera|iphonography|smartphone|This Strange Effect|The Shacks',
#   'views': 183325,
#   'likes': 1700,
#   'dislikes': 570,
#   'comment_total': 0,
#   'thumbnail_link': 'https://i.ytimg.com/vi/REZl-ANYKKY/default.jpg',
#   'date': datetime.datetime(2020, 1, 5, 0, 1),
#   'kind': 'youtube#videoCategory',
#   'etag': '"m2yskBQFythfE4irbTIeOgYYfBU/w5HjcTD82G_XA3xBctS30zS-JpQ"',
#   'snippet_channelId': 'UCBR8-60-B28hp2BmDPdntcQ',
#   'snippet_title': 'Science & Technology',
#   'snippet_assignable': True,
#   'ID': 4539}]

# %% [markdown]
# ## Question 2

# %%
import numpy as np
cur=collection.distinct('category_id')
len(np.array(cur))
# Out:
# 32

# %% [markdown]
# ## Question 3

# %% [markdown]
# #déjà fait je crois
# cur=collection.aggregate([{ "$project" : { "all_tags" : { "$split": ["$tags", "|"] }} },{"$limit":5}])
# list(cur)

# %%
map_function = '''function(){emit(this.video_id, this.tags)}'''
reduce_function = '''function(key,values){return values.toString().split("|")}'''
out = '''{ out:"tags"}'''
result = collection.map_reduce(
        map_function, 
        reduce_function,
        out)

# %%
dictio=list(result.find())

# %%
dictio[1]['value']
# Out:
# ['adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spider,animal adventure,jungle spider,wandering spider,brazilian wandering spider,banana spider,dangerous jungle spider,adventure,adventurous,animals,breaking,breaking trail,coyote,coyote peterson,peterson,snapping turtle,trail,wild,black widow spider,spider,brave,brave wilderness,wildlife,black widow challenge,spider bite,brown recluse,holding a black widow,deadly spider,dangerous spider,scary,golden orb weaver,big creepy spider,spider challenge,giant spide ...

# %%
len(dictio)
# Out:
# 2365

# %%
for i in range(len(dictio)):
    collection.update_one({'video_id':dictio[i]["_id"]},{"$set":{'tags':dictio[i]['value']}})

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5fc2b31b3f42e014b17a1eb7'),
#  'video_id': 'XpVt6Z1Gjjo',
#  'title': '1 YEAR OF VLOGGING -- HOW LOGAN PAUL CHANGED YOUTUBE FOREVER!',
#  'channel_title': 'Logan Paul Vlogs',
#  'category_id': 24,
#  'tags': ['logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 life,logan paul vlog,logan paul,logan,paul,olympics,logan paul youtube,vlog,daily,comedy,hollywood,parrot,maverick,bird,maverick clothes,diamond play button,logan paul diamond play button,10M subscribers,logan paul 1 year vlogging,1 year vlog,dwarf mamba play button,logan paul history,youtube history,10M,10M plaque,youtube button,diamond button,logang,logang 4 l ...
#  'views': 4394029,
#  'likes': 320053,
#  'dislikes': 5931,
#  'comment_total': 46245,
#  'thumbnail_link': 'https://i.ytimg.com/vi/XpVt6Z1Gjjo/default.jpg',
#  'date': 13.09}

# %% [markdown]
# ## Question 4

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$video_id", "averageviewsnumber" : {"$avg" : "$views"}}},{"$sort":{"averageviewsnumber":-1}},{"$limit":15}])
list(cur)
# Out:
# [{'_id': 'tt2k8PGm-TI', 'averageviewsnumber': 36323498.0},
#  {'_id': 'MBdVXkSdhwU', 'averageviewsnumber': 32626121.0},
#  {'_id': 'LunHybOKIjU', 'averageviewsnumber': 25119483.875},
#  {'_id': 'Q0CbN8sfihY', 'averageviewsnumber': 20393443.6},
#  {'_id': 'SHq2qrFUlGY', 'averageviewsnumber': 19015506.14285714},
#  {'_id': 'r9-DM9uBtVI', 'averageviewsnumber': 15483115.333333334},
#  {'_id': 'D59v74k5flU', 'averageviewsnumber': 14970548.75},
#  {'_id': 'K4wEI5zhHB0', 'averageviewsnumber': 14626238.27631579},
#  {'_id': '3y5A4paFOb4', 'averageviewsnumber': 14241921.166666666},
#  {'_id': 'GO6qs83CHpc', 'averageviewsnumber': 13986574.4},
#  {'_id': 'dA5qYrboTUE', 'averageviewsnumber': 13752002.0},
#  {'_id': 'AX8-YzMKZhQ', 'averageviewsnumber': 13728070.0},
#  {'_id': 'LcZ2AuvxXNA', 'averageviewsnumber': 12163449.0},
#  {'_id': 'FSOxXsYVJMQ', 'averageviewsnumber': 11650531.25},
#  {'_id': 't2oVUxTV4WA', 'averageviewsnumber': 10633875.0}]

# %% [markdown]
# ## Question 5

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$category_id", "averageviewsnumber" : {"$avg" : "$views"}}}])
list(cur)
# Out:
# [{'_id': '28', 'averageviewsnumber': None},
#  {'_id': 27, 'averageviewsnumber': 547582.4700598803},
#  {'_id': 43, 'averageviewsnumber': 8492.5},
#  {'_id': '22', 'averageviewsnumber': None},
#  {'_id': None, 'averageviewsnumber': None},
#  {'_id': 22, 'averageviewsnumber': 971532.7573696146},
#  {'_id': '15', 'averageviewsnumber': None},
#  {'_id': 20, 'averageviewsnumber': 681081.8170731707},
#  {'_id': 19, 'averageviewsnumber': 464041.0833333333},
#  {'_id': '26', 'averageviewsnumber': None},
#  {'_id': 23, 'averageviewsnumber': 1240073.294039735},
#  {'_id': 15, 'averageviewsnumber': 651404.3879310344},
#  {'_id': '10', 'averageviewsnumber': None},
#  {'_id': '1', 'averageviewsnumber': None},
#  {'_id': '2', 'averageviewsnumber': None},
#  {'_id': 17, 'averageviewsnumber': 728434.3243902439},
#  {'_id': 10, 'averageviewsnumber': 1176553.612},
#  {'_id': '24', 'averageviewsnumber': None},
#  {'_id': 25, 'averageviewsnumber': 540955.5569823436},
#  {'_id': '27', 'averageviewsnumber': None},
#  {'_id': '20', 'averageviewsnumber': None},
#  {'_id': '43', 'averageviewsnumber': None},
#  {'_id': 2, 'averageviewsnumber': 607693.8706896552},
#  {'_id': '19', 'averageviewsnumber': None},
#  {'_id': 1, 'averageviewsnumber': 1039472.6560846561},
#  {'_id': '17', 'averageviewsnumber': None},
#  {'_id': 24, 'averageviewsnumber': 1155003.3148317789},
#  {'_id': 28, 'averageviewsnumber': 925633.4766306471},
#  {'_id': '29', 'averageviewsnumber': None},
#  {'_id': 26, 'averageviewsnumber': 537665.1806674339},
#  {'_id': '25', 'averageviewsnumber': None},
#  {'_id': '23', 'averageviewsnumber': None},
#  {'_id': 29, 'averageviewsnumber': 1110334.2142857143}]

# %% [markdown]
# ## Question 6

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$channel_title", "avglikes" : {"$avg" : "$likes"}}},{"$sort":{"avglikes":-1}},{"$limit":1}])
list(cur)
# Out:
# [{'_id': 'ZaynVEVO', 'avglikes': 1431683.0}]
