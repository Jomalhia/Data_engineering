# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
collection.delete_many({})

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongo")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# /root/.local/share/virtualenvs/code-AFz48Hjb/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6,8,10,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %%
df_ks['goal']=df_ks['goal'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['pledged']=df_ks['pledged'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['backers']=df_ks['backers'].apply(lambda x: pd.to_numeric(x, errors='coerce'))
df_ks['usd pledged']=df_ks['usd pledged'].apply(lambda x: pd.to_numeric(x, errors='coerce',downcast='float'))

# %%
df_ks.shape
# Out:
# (150000, 14)

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
df_ks.dropna(axis=0,inplace=True)

# %%
df_sample=df_ks.sample(frac=1/4,axis=0)
df_sample.shape
# Out:
# (37129, 14)

# %%
df_ks.dtypes
# Out:
# ID                    int64
# name                 object
# category             object
# main_category        object
# currency             object
# deadline             object
# goal                float64
# launched             object
# pledged             float64
# state                object
# backers             float64
# country              object
# usd pledged         float64
# usd_pledged_real    float64
# dtype: object

# %% [markdown]
# import datetime
# for i in range(len(df_ks)):
#     datetime.datetime.strptime(df_ks['deadline'].iloc[i], '%Y%m%d')

# %%
df_ks['launched']=pd.to_datetime(df_ks['launched'])

# %%
df_ks['deadline']=pd.to_datetime(df_ks['deadline'])

# %%
df_ks.dtypes
# Out:
# ID                           int64
# name                        object
# category                    object
# main_category               object
# currency                    object
# deadline            datetime64[ns]
# goal                       float64
# launched            datetime64[ns]
# pledged                    float64
# state                       object
# backers                    float64
# country                     object
# usd pledged                float64
# usd_pledged_real           float64
# dtype: object

# %% [markdown]
# ### Importer les données

# %%
def slice_generator(df, chunk_size=10):
    current_row = 0
    total_rows = df.shape[0]
    while current_row < total_rows:
        yield df[current_row:current_row + chunk_size]
        current_row += chunk_size

# %%
for df_chunk in slice_generator(df_sample):
    records = df_chunk.to_dict(orient='records')
    collection.insert_many(records)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('5fccbfdc247348e355264517'),
#  'ID': 1845007191,
#  'name': 'Going To The Open, The Story of a Pool Underdog (Canceled)',
#  'category': 'Nonfiction',
#  'main_category': 'Publishing',
#  'currency': 'USD',
#  'deadline': '2014-02-03',
#  'goal': 3000.0,
#  'launched': '2013-12-05 23:09:50',
#  'pledged': 0.0,
#  'state': 'canceled',
#  'backers': 0.0,
#  'country': 'US',
#  'usd pledged': 0.0,
#  'usd_pledged_real': 0.0}

# %% [markdown]
# ## Question 1

# %% [markdown]
# cur=collection.find().sort('backers',-1).limit(5)
# list(cur)

# %%
cur = collection.aggregate([{"$group" : {"_id" : "$ID", "averagebackers" : {"$avg" : "$backers"}}},{"$sort":{"averagebackers":-1}},{"$limit":5}])
list(cur)
# Out:
# [{'_id': 1386523707, 'averagebackers': 154926.0},
#  {'_id': 2103598555, 'averagebackers': 66673.0},
#  {'_id': 1033978702, 'averagebackers': 63416.0},
#  {'_id': 342886736, 'averagebackers': 62642.0},
#  {'_id': 951470114, 'averagebackers': 28138.0}]

# %% [markdown]
# ## Question 2

# %%
cur=collection.find({"state":"successful"})

len(list(cur))
# Out:
# 13351

# %%
cur=collection.aggregate([{"$group" : {"_id" : "$state", "totalnumber" : {"$sum" : 1}}}])
list(cur)
# Out:
# [{'_id': 'canceled', 'totalnumber': 3838},
#  {'_id': 'successful', 'totalnumber': 13351},
#  {'_id': 'suspended', 'totalnumber': 193},
#  {'_id': 'live', 'totalnumber': 279},
#  {'_id': 'failed', 'totalnumber': 19468}]

# %% [markdown]
# ## Question 3

# %%
cur=collection.aggregate([{"$group":{"_id":"$category","total":{"$sum":1}}}])
list(cur)
# Out:
# [{'_id': 'Festivals', 'total': 77},
#  {'_id': 'Theater', 'total': 711},
#  {'_id': 'Art Books', 'total': 297},
#  {'_id': 'Civic Design', 'total': 33},
#  {'_id': 'Classical Music', 'total': 253},
#  {'_id': 'Woodworking', 'total': 122},
#  {'_id': 'Webcomics', 'total': 69},
#  {'_id': 'Family', 'total': 33},
#  {'_id': 'Accessories', 'total': 311},
#  {'_id': 'Product Design', 'total': 2185},
#  {'_id': 'Experimental', 'total': 83},
#  {'_id': 'People', 'total': 113},
#  {'_id': 'Apparel', 'total': 707},
#  {'_id': 'Flight', 'total': 45},
#  {'_id': 'Art', 'total': 846},
#  {'_id': 'Ready-to-wear', 'total': 95},
#  {'_id': 'Video Art', 'total': 14},
#  {'_id': 'Music', 'total': 1337},
#  {'_id': 'Photography', 'total': 560},
#  {'_id': 'Nonfiction', 'total': 863},
#  {'_id': 'Knitting', 'total': 15},
#  {'_id': 'Digital Art', 'total': 116},
#  {'_id': 'Academic', 'total': 98},
#  {'_id': 'Gadgets', 'total': 311},
#  {'_id': 'Young Adult', 'total': 76},
#  {'_id': 'Horror', 'total': 133},
#  {'_id': 'Residencies', 'total': 7},
#  {'_id': 'Fashion', 'total': 849},
#  {'_id': 'Hardware', 'total': 383},
#  {'_id': 'Playing Cards', 'total': 245},
#  {'_id': 'Restaurants', 'total': 278},
#  {'_id': 'Pottery', 'total': 8},
#  {'_id': 'Installations', 'total': 42},
#  {'_id': 'Sound', 'total': 65},
#  {'_id': 'Crafts', 'total': 405},
#  {'_id': 'Hip-Hop', 'total': 369},
#  {'_id': 'DIY', 'total': 119},
#  {'_id': 'Journalism', 'total': 163},
#  {'_id': 'Jazz', 'total': 190},
#  {'_id': 'Cookbooks', 'total': 58},
#  {'_id': 'Software', 'total': 294},
#  {'_id': 'Photo', 'total': 15},
#  {'_id': 'Childrenswear', 'total': 50},
#  {'_id': 'Fabrication Tools', 'total': 27},
#  {'_id': 'Music Videos', 'total': 76},
#  {'_id': 'Shorts', 'total': 1182},
#  {'_id': 'Anthologies', 'total': 82},
#  {'_id': 'Latin', 'total': 14},
#  {'_id': 'Sculpture', 'total': 175},
#  {'_id': 'Glass', 'total': 11},
#  {'_id': 'Taxidermy', 'total': 2},
#  {'_id': 'Stationery', 'total': 24},
#  {'_id': 'DIY Electronics', 'total': 78},
#  {'_id': 'Fine Art', 'total': 74},
#  {'_id': 'Mixed Media', 'total': 290},
#  {'_id': 'Science Fiction', 'total': 73},
#  {'_id': 'Electronic Music', 'total': 208},
#  {'_id': 'Architecture', 'total': 79},
#  {'_id': 'Film & Video', 'total': 898},
#  {'_id': 'Painting', 'total': 320},
#  {'_id': 'Spaces', 'total': 77},
#  {'_id': 'Webseries', 'total': 583},
#  {'_id': 'Metal', 'total': 86},
#  {'_id': 'Camera Equipment', 'total': 41},
#  {'_id': 'Pet Fashion', 'total': 11},
#  {'_id': 'Places', 'total': 74},
#  {'_id': 'Farms', 'total': 118},
#  {'_id': 'Footwear', 'total': 94},
#  {'_id': 'Crochet', 'total': 17},
#  {'_id': "Children's Books", 'total': 695},
#  {'_id': 'Plays', 'total': 149},
#  {'_id': 'Space Exploration', 'total': 30},
#  {'_id': 'Conceptual Art', 'total': 99},
#  {'_id': 'Video', 'total': 46},
#  {'_id': 'Typography', 'total': 8},
#  {'_id': 'Couture', 'total': 29},
#  {'_id': 'Tabletop Games', 'total': 1351},
#  {'_id': 'Live Games', 'total': 104},
#  {'_id': 'Illustration', 'total': 331},
#  {'_id': 'World Music', 'total': 219},
#  {'_id': 'Events', 'total': 95},
#  {'_id': 'Faith', 'total': 112},
#  {'_id': 'Fantasy', 'total': 29},
#  {'_id': 'Apps', 'total': 621},
#  {'_id': 'Pop', 'total': 320},
#  {'_id': 'Mobile Games', 'total': 180},
#  {'_id': 'Literary Journals', 'total': 23},
#  {'_id': 'Graphic Novels', 'total': 182},
#  {'_id': 'Drama', 'total': 214},
#  {'_id': 'Weaving', 'total': 5},
#  {'_id': 'Performances', 'total': 85},
#  {'_id': 'Musical', 'total': 88},
#  {'_id': 'Audio', 'total': 43},
#  {'_id': 'Drinks', 'total': 270},
#  {'_id': 'Poetry', 'total': 142},
#  {'_id': 'Nature', 'total': 49},
#  {'_id': 'Literary Spaces', 'total': 3},
#  {'_id': 'Blues', 'total': 27},
#  {'_id': 'Translations', 'total': 19},
#  {'_id': 'Bacon', 'total': 23},
#  {'_id': 'Workshops', 'total': 19},
#  {'_id': 'R&B', 'total': 51},
#  {'_id': 'Thrillers', 'total': 76},
#  {'_id': 'Web', 'total': 479},
#  {'_id': 'Romance', 'total': 18},
#  {'_id': 'Candles', 'total': 42},
#  {'_id': 'Food', 'total': 1144},
#  {'_id': 'Country & Folk', 'total': 457},
#  {'_id': 'Narrative Film', 'total': 534},
#  {'_id': 'Design', 'total': 409},
#  {'_id': '3D Printing', 'total': 70},
#  {'_id': 'Printing', 'total': 25},
#  {'_id': 'Food Trucks', 'total': 179},
#  {'_id': 'Jewelry', 'total': 122},
#  {'_id': 'Documentary', 'total': 1629},
#  {'_id': 'Television', 'total': 111},
#  {'_id': 'Makerspaces', 'total': 16},
#  {'_id': 'Comic Books', 'total': 261},
#  {'_id': 'Zines', 'total': 34},
#  {'_id': 'Punk', 'total': 36},
#  {'_id': 'Ceramics', 'total': 29},
#  {'_id': 'Photobooks', 'total': 162},
#  {'_id': 'Graphic Design', 'total': 191},
#  {'_id': 'Games', 'total': 310},
#  {'_id': 'Publishing', 'total': 555},
#  {'_id': 'Robots', 'total': 56},
#  {'_id': 'Vegan', 'total': 62},
#  {'_id': 'Community Gardens', 'total': 24},
#  {'_id': 'Public Art', 'total': 325},
#  {'_id': 'Immersive', 'total': 29},
#  {'_id': 'Movie Theaters', 'total': 23},
#  {'_id': 'Quilts', 'total': 8},
#  {'_id': 'Rock', 'total': 615},
#  {'_id': 'Fiction', 'total': 915},
#  {'_id': 'Print', 'total': 71},
#  {'_id': 'Dance', 'total': 205},
#  {'_id': 'Animation', 'total': 244},
#  {'_id': 'Comedy', 'total': 230},
#  {'_id': 'Puzzles', 'total': 20},
#  {'_id': 'Gaming Hardware', 'total': 40},
#  {'_id': 'Periodicals', 'total': 126},
#  {'_id': 'Embroidery', 'total': 9},
#  {'_id': 'Wearables', 'total': 136},
#  {'_id': "Farmer's Markets", 'total': 48},
#  {'_id': 'Video Games', 'total': 1222},
#  {'_id': 'Performance Art', 'total': 215},
#  {'_id': 'Comics', 'total': 462},
#  {'_id': 'Animals', 'total': 33},
#  {'_id': 'Small Batch', 'total': 167},
#  {'_id': 'Radio & Podcasts', 'total': 94},
#  {'_id': 'Interactive Design', 'total': 38},
#  {'_id': 'Calendars', 'total': 33},
#  {'_id': 'Textiles', 'total': 20},
#  {'_id': 'Indie Rock', 'total': 543},
#  {'_id': 'Chiptune', 'total': 2},
#  {'_id': 'Kids', 'total': 27},
#  {'_id': 'Letterpress', 'total': 8},
#  {'_id': 'Action', 'total': 74},
#  {'_id': 'Technology', 'total': 698}]

# %% [markdown]
# ## Question 4

# %% [markdown]
# collection.find({"launched":{ "$lte" :  "2015-12-31"}}).count(True)

# %%
cur=collection.find({"launched":{ "$lte" :  "2015-12-31"}})

len(list(cur))
# Out:
# 26313

# %% [markdown]
# import datetime
# start=datetime.datetime(2016,1,1)
#
# type(start)
# print(start)

# %% [markdown]
# cur=collection.find({"launched":{"$lt":start}})
# list(cur)

# %% [markdown]
# cur=collection.find({"deadline" : { "$gt" : start}})
# len(list(cur))

# %% [markdown]
# ## Question 5

# %%
cur=collection.find({"pledged":{ "$gte" :  200000}})
list(cur)
# Out:
# [{'_id': ObjectId('5fccbfdc247348e35526453e'),
#   'ID': 879028973,
#   'name': "RiffTrax Live '17: Samurai Cop, Beach Party & Mystery Title!",
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2017-03-26',
#   'goal': 250000.0,
#   'launched': '2017-02-21 20:59:19',
#   'pledged': 430620.15,
#   'state': 'successful',
#   'backers': 8602.0,
#   'country': 'US',
#   'usd pledged': 83630.5234375,
#   'usd_pledged_real': 430620.15},
#  {'_id': ObjectId('5fccbfdc247348e3552645a1'),
#   'ID': 909248984,
#   'name': 'Redux COURG - Hybrid Watches with Missions to Tackle',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-08-20',
#   'goal': 30000.0,
#   'launched': '2015-07-21 19:01:41',
#   'pledged': 692912.0,
#   'state': 'successful',
#   'backers': 2200.0,
#   'country': 'US',
#   'usd pledged': 692912.0,
#   'usd_pledged_real': 692912.0},
#  {'_id': ObjectId('5fccbfdc247348e3552645f1'),
#   'ID': 918788305,
#   'name': "DAN Cases A4-SFX - The World's Smallest Gaming Tower Case",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-06-28',
#   'goal': 125000.0,
#   'launched': '2016-05-29 17:45:23',
#   'pledged': 396659.0,
#   'state': 'successful',
#   'backers': 1530.0,
#   'country': 'DE',
#   'usd pledged': 440892.40625,
#   'usd_pledged_real': 441679.37911298673},
#  {'_id': ObjectId('5fccbfdd247348e3552648b8'),
#   'ID': 1104229032,
#   'name': 'Ragnarok Playing Cards',
#   'category': 'Playing Cards',
#   'main_category': 'Games',
#   'currency': 'DKK',
#   'deadline': '2017-11-15',
#   'goal': 115000.0,
#   'launched': '2017-10-17 18:21:04',
#   'pledged': 629351.0,
#   'state': 'successful',
#   'backers': 1669.0,
#   'country': 'DK',
#   'usd pledged': 26586.99117432,
#   'usd_pledged_real': 99760.80271375582},
#  {'_id': ObjectId('5fccbfdd247348e3552648f8'),
#   'ID': 1753510637,
#   'name': 'Napoli Multi-Fueled Outdoor Pizza Oven',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-12-07',
#   'goal': 10000.0,
#   'launched': '2017-11-07 14:20:06',
#   'pledged': 207267.0,
#   'state': 'successful',
#   'backers': 755.0,
#   'country': 'US',
#   'usd pledged': 1096.0,
#   'usd_pledged_real': 207267.0},
#  {'_id': ObjectId('5fccbfdd247348e3552649a6'),
#   'ID': 2124046131,
#   'name': 'Boss Monster: The Next Level',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-28',
#   'goal': 25000.0,
#   'launched': '2015-04-13 15:03:50',
#   'pledged': 335618.85,
#   'state': 'successful',
#   'backers': 6891.0,
#   'country': 'US',
#   'usd pledged': 335618.85,
#   'usd_pledged_real': 335618.85},
#  {'_id': ObjectId('5fccbfdd247348e3552649e5'),
#   'ID': 271631066,
#   'name': 'MYTH: Journeyman',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-29',
#   'goal': 80000.0,
#   'launched': '2015-03-09 16:58:49',
#   'pledged': 972886.0,
#   'state': 'successful',
#   'backers': 4739.0,
#   'country': 'US',
#   'usd pledged': 972886.0,
#   'usd_pledged_real': 972886.0},
#  {'_id': ObjectId('5fccbfdd247348e355264a32'),
#   'ID': 951470114,
#   'name': 'The Rocketbook Everlast Notebook',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-01-15',
#   'goal': 26000.0,
#   'launched': '2016-11-16 16:21:27',
#   'pledged': 1823227.5,
#   'state': 'successful',
#   'backers': 28138.0,
#   'country': 'US',
#   'usd pledged': 16942.0,
#   'usd_pledged_real': 1823227.5},
#  {'_id': ObjectId('5fccbfdd247348e355264b76'),
#   'ID': 1498002503,
#   'name': 'Fairytale Games: The Miniatures Campaign',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-10-22',
#   'goal': 25000.0,
#   'launched': '2013-09-17 19:31:05',
#   'pledged': 236625.13,
#   'state': 'successful',
#   'backers': 1269.0,
#   'country': 'US',
#   'usd pledged': 236625.13,
#   'usd_pledged_real': 236625.13},
#  {'_id': ObjectId('5fccbfdd247348e355264bb2'),
#   'ID': 1575904354,
#   'name': 'Edible Cutlery: The Future of Eco Friendly Utensils',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-17',
#   'goal': 20000.0,
#   'launched': '2016-03-18 16:08:44',
#   'pledged': 278874.0,
#   'state': 'successful',
#   'backers': 9293.0,
#   'country': 'US',
#   'usd pledged': 278874.0,
#   'usd_pledged_real': 278874.0},
#  {'_id': ObjectId('5fccbfdd247348e355264c09'),
#   'ID': 905332510,
#   'name': 'Playing Lean relaunch: Play Leaner',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'NOK',
#   'deadline': '2015-06-03',
#   'goal': 75000.0,
#   'launched': '2015-05-04 09:01:29',
#   'pledged': 385711.24,
#   'state': 'successful',
#   'backers': 357.0,
#   'country': 'NO',
#   'usd pledged': 50736.78515625,
#   'usd_pledged_real': 49122.04887864394},
#  {'_id': ObjectId('5fccbfdd247348e355264ca0'),
#   'ID': 752292713,
#   'name': 'Too Many Bones',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-03-11',
#   'goal': 42000.0,
#   'launched': '2016-02-16 19:03:08',
#   'pledged': 270290.0,
#   'state': 'successful',
#   'backers': 1584.0,
#   'country': 'US',
#   'usd pledged': 270290.0,
#   'usd_pledged_real': 270290.0},
#  {'_id': ObjectId('5fccbfdd247348e355264cd4'),
#   'ID': 376922208,
#   'name': 'Chipolo - Bluetooth Item Finder for iPhone and Android',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2013-11-15',
#   'goal': 15000.0,
#   'launched': '2013-10-21 06:51:41',
#   'pledged': 293014.45,
#   'state': 'successful',
#   'backers': 5329.0,
#   'country': 'US',
#   'usd pledged': 293014.45,
#   'usd_pledged_real': 293014.45},
#  {'_id': ObjectId('5fccbfdd247348e355264d08'),
#   'ID': 1860876944,
#   'name': 'WATCHES CRAFTED FROM WOOD AND STEEL WITH A MARITIME TOUCH',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'DKK',
#   'deadline': '2015-11-30',
#   'goal': 150000.0,
#   'launched': '2015-10-29 17:48:59',
#   'pledged': 655672.0,
#   'state': 'successful',
#   'backers': 429.0,
#   'country': 'DK',
#   'usd pledged': 97008.48205472,
#   'usd_pledged_real': 95815.05458052637},
#  {'_id': ObjectId('5fccbfdd247348e355264d37'),
#   'ID': 635657578,
#   'name': 'Vue: Your Everyday Smart Glasses',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-12-10',
#   'goal': 50000.0,
#   'launched': '2016-10-25 16:53:31',
#   'pledged': 2215583.0,
#   'state': 'successful',
#   'backers': 10410.0,
#   'country': 'US',
#   'usd pledged': 58819.0,
#   'usd_pledged_real': 2215583.0},
#  {'_id': ObjectId('5fccbfdd247348e355264d8c'),
#   'ID': 1349593857,
#   'name': 'Reissue of the 1975 NASA Graphics Standards Manual.',
#   'category': 'Graphic Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-10-05',
#   'goal': 158000.0,
#   'launched': '2015-09-01 05:56:35',
#   'pledged': 941966.92,
#   'state': 'successful',
#   'backers': 8798.0,
#   'country': 'US',
#   'usd pledged': 941966.92,
#   'usd_pledged_real': 941966.92},
#  {'_id': ObjectId('5fccbfdd247348e355264db5'),
#   'ID': 399039802,
#   'name': 'Tesla vs. Edison',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-04-03',
#   'goal': 20000.0,
#   'launched': '2015-03-05 06:01:06',
#   'pledged': 202928.5,
#   'state': 'successful',
#   'backers': 3562.0,
#   'country': 'US',
#   'usd pledged': 202928.5,
#   'usd_pledged_real': 202928.5},
#  {'_id': ObjectId('5fccbfdd247348e355264dca'),
#   'ID': 874722536,
#   'name': 'The ultimate sleep sanctuary: Kokoon EEG headphones',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-10',
#   'goal': 100000.0,
#   'launched': '2015-05-11 17:00:32',
#   'pledged': 1936825.0,
#   'state': 'successful',
#   'backers': 8489.0,
#   'country': 'US',
#   'usd pledged': 1936825.0,
#   'usd_pledged_real': 1936825.0},
#  {'_id': ObjectId('5fccbfde247348e355264fea'),
#   'ID': 2017949679,
#   'name': 'STRAFEï¿½',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-02-19',
#   'goal': 185096.0,
#   'launched': '2015-01-20 14:30:11',
#   'pledged': 207847.4,
#   'state': 'successful',
#   'backers': 4953.0,
#   'country': 'US',
#   'usd pledged': 207847.40625,
#   'usd_pledged_real': 207847.4},
#  {'_id': ObjectId('5fccbfde247348e3552650c4'),
#   'ID': 49755697,
#   'name': 'IllumiBowl 2: Toilet Night Light SharkTank Upgrade! Only $10',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-26',
#   'goal': 10000.0,
#   'launched': '2016-10-27 21:17:29',
#   'pledged': 226824.0,
#   'state': 'successful',
#   'backers': 7885.0,
#   'country': 'US',
#   'usd pledged': 44778.0,
#   'usd_pledged_real': 226824.0},
#  {'_id': ObjectId('5fccbfde247348e355265114'),
#   'ID': 1066172240,
#   'name': 'Rum & Bones: Second Tide',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-04-29',
#   'goal': 80000.0,
#   'launched': '2016-04-11 21:01:01',
#   'pledged': 917864.02,
#   'state': 'successful',
#   'backers': 5794.0,
#   'country': 'US',
#   'usd pledged': 917864.02,
#   'usd_pledged_real': 917864.02},
#  {'_id': ObjectId('5fccbfde247348e355265155'),
#   'ID': 1788713718,
#   'name': 'Orbitkey 2.0 - Carry Your Keys Better',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-04',
#   'goal': 20000.0,
#   'launched': '2016-07-06 02:01:49',
#   'pledged': 552501.0,
#   'state': 'successful',
#   'backers': 10230.0,
#   'country': 'US',
#   'usd pledged': 102099.0,
#   'usd_pledged_real': 552501.0},
#  {'_id': ObjectId('5fccbfde247348e3552651dd'),
#   'ID': 1479488174,
#   'name': 'Photography Gloves: Extend your session in style',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'NOK',
#   'deadline': '2015-12-28',
#   'goal': 120000.0,
#   'launched': '2015-11-26 17:39:38',
#   'pledged': 355520.0,
#   'state': 'successful',
#   'backers': 610.0,
#   'country': 'NO',
#   'usd pledged': 41198.350864,
#   'usd_pledged_real': 40305.648141849764},
#  {'_id': ObjectId('5fccbfde247348e35526524b'),
#   'ID': 1060828669,
#   'name': 'ANTVR KIT: All-IN-ONE Universal Virtual Reality Kit',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-06-23',
#   'goal': 200000.0,
#   'launched': '2014-05-14 13:26:19',
#   'pledged': 260834.88,
#   'state': 'successful',
#   'backers': 681.0,
#   'country': 'US',
#   'usd pledged': 260834.875,
#   'usd_pledged_real': 260834.88},
#  {'_id': ObjectId('5fccbfde247348e3552652f9'),
#   'ID': 1305164948,
#   'name': 'GIR Tongs + Whisks | Squeeze. Lock. Whisk. Repeat.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-11-30',
#   'goal': 20000.0,
#   'launched': '2017-10-24 19:05:40',
#   'pledged': 213359.0,
#   'state': 'successful',
#   'backers': 3459.0,
#   'country': 'US',
#   'usd pledged': 54815.0,
#   'usd_pledged_real': 213359.0},
#  {'_id': ObjectId('5fccbfde247348e355265305'),
#   'ID': 2124715052,
#   'name': 'Foundr V1.0: Lessons From The Greatest Entrepreneurs Today',
#   'category': 'Zines',
#   'main_category': 'Publishing',
#   'currency': 'AUD',
#   'deadline': '2016-12-15',
#   'goal': 50000.0,
#   'launched': '2016-11-15 09:55:51',
#   'pledged': 200589.0,
#   'state': 'successful',
#   'backers': 1862.0,
#   'country': 'AU',
#   'usd pledged': 11177.1826171875,
#   'usd_pledged_real': 147059.38416422287},
#  {'_id': ObjectId('5fccbfde247348e35526550d'),
#   'ID': 1000629643,
#   'name': "ODIN: Android 'Smart' Projector to Carry in Your Pocket",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-08',
#   'goal': 250000.0,
#   'launched': '2014-05-28 13:54:18',
#   'pledged': 268192.0,
#   'state': 'successful',
#   'backers': 561.0,
#   'country': 'US',
#   'usd pledged': 268192.0,
#   'usd_pledged_real': 268192.0},
#  {'_id': ObjectId('5fccbfdf247348e3552656e6'),
#   'ID': 345927017,
#   'name': 'PocketScan',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-07-16',
#   'goal': 50000.0,
#   'launched': '2014-06-16 14:41:13',
#   'pledged': 542732.32,
#   'state': 'successful',
#   'backers': 4586.0,
#   'country': 'US',
#   'usd pledged': 542732.32,
#   'usd_pledged_real': 542732.32},
#  {'_id': ObjectId('5fccbfdf247348e3552656f4'),
#   'ID': 1420270001,
#   'name': 'Grim Dawn',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-05-19',
#   'goal': 280000.0,
#   'launched': '2012-04-17 12:34:43',
#   'pledged': 537515.31,
#   'state': 'successful',
#   'backers': 12457.0,
#   'country': 'US',
#   'usd pledged': 537515.31,
#   'usd_pledged_real': 537515.31},
#  {'_id': ObjectId('5fccbfdf247348e35526577b'),
#   'ID': 63698042,
#   'name': "The World's First Full HD 360ï¿½ Camera",
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2014-07-04',
#   'goal': 150000.0,
#   'launched': '2014-05-20 15:59:54',
#   'pledged': 1419068.86,
#   'state': 'successful',
#   'backers': 3916.0,
#   'country': 'US',
#   'usd pledged': 1419068.86,
#   'usd_pledged_real': 1419068.86},
#  {'_id': ObjectId('5fccbfdf247348e3552657d7'),
#   'ID': 861052408,
#   'name': 'A quality Dillenger folding electric bike for under $400.00!',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'AUD',
#   'deadline': '2015-02-27',
#   'goal': 30000.0,
#   'launched': '2015-01-13 23:55:29',
#   'pledged': 209692.0,
#   'state': 'successful',
#   'backers': 411.0,
#   'country': 'AU',
#   'usd pledged': 172833.23772176,
#   'usd_pledged_real': 164155.31548457805},
#  {'_id': ObjectId('5fccbfdf247348e3552657e9'),
#   'ID': 504955583,
#   'name': 'Wiral LITE | The Easy Cable Cam, For Impossible Film Shots',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-11-16',
#   'goal': 30000.0,
#   'launched': '2017-10-17 17:55:55',
#   'pledged': 1055480.02,
#   'state': 'successful',
#   'backers': 4126.0,
#   'country': 'US',
#   'usd pledged': 143654.96,
#   'usd_pledged_real': 1055480.02},
#  {'_id': ObjectId('5fccbfdf247348e355265810'),
#   'ID': 197928689,
#   'name': 'Fugitive',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-07-10',
#   'goal': 5000.0,
#   'launched': '2016-06-15 17:20:41',
#   'pledged': 228004.46,
#   'state': 'successful',
#   'backers': 7514.0,
#   'country': 'US',
#   'usd pledged': 184336.46,
#   'usd_pledged_real': 228004.46},
#  {'_id': ObjectId('5fccbfdf247348e355265889'),
#   'ID': 137358605,
#   'name': "FLOATTI - The World's First SUPER SUITCASE",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-05-06',
#   'goal': 100000.0,
#   'launched': '2016-03-29 13:49:28',
#   'pledged': 530838.0,
#   'state': 'successful',
#   'backers': 1159.0,
#   'country': 'US',
#   'usd pledged': 530838.0,
#   'usd_pledged_real': 530838.0},
#  {'_id': ObjectId('5fccbfdf247348e3552658af'),
#   'ID': 1764528620,
#   'name': 'XPlotter - Desktop Plotter, Laser Cutter and Engraver',
#   'category': 'Robots',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-04-01',
#   'goal': 5000.0,
#   'launched': '2017-01-31 16:38:39',
#   'pledged': 403700.99,
#   'state': 'successful',
#   'backers': 827.0,
#   'country': 'US',
#   'usd pledged': 12928.0,
#   'usd_pledged_real': 403700.99},
#  {'_id': ObjectId('5fccbfdf247348e35526597a'),
#   'ID': 1462900388,
#   'name': 'FlowMotion Smartphone Stabilizer | The End of Shaky Videos',
#   'category': 'Camera Equipment',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-01-10',
#   'goal': 30000.0,
#   'launched': '2016-11-22 18:05:33',
#   'pledged': 1325241.0,
#   'state': 'successful',
#   'backers': 5508.0,
#   'country': 'US',
#   'usd pledged': 61578.0,
#   'usd_pledged_real': 1325241.0},
#  {'_id': ObjectId('5fccbfdf247348e3552659c8'),
#   'ID': 1690292487,
#   'name': 'RE-LOAD by Archon Studio',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-05-15',
#   'goal': 10000.0,
#   'launched': '2017-05-01 15:59:44',
#   'pledged': 228660.0,
#   'state': 'successful',
#   'backers': 1365.0,
#   'country': 'US',
#   'usd pledged': 82086.0,
#   'usd_pledged_real': 228660.0},
#  {'_id': ObjectId('5fccbfdf247348e355265a5c'),
#   'ID': 829444599,
#   'name': 'Medical Inc. The Movie',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-06-01',
#   'goal': 75000.0,
#   'launched': '2012-04-26 22:07:12',
#   'pledged': 241948.0,
#   'state': 'successful',
#   'backers': 1417.0,
#   'country': 'US',
#   'usd pledged': 241948.0,
#   'usd_pledged_real': 241948.0},
#  {'_id': ObjectId('5fccbfdf247348e355265b1a'),
#   'ID': 1105529538,
#   'name': 'Starfinder Masterclass Miniatures',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-10-18',
#   'goal': 50000.0,
#   'launched': '2017-09-27 18:07:05',
#   'pledged': 457539.0,
#   'state': 'successful',
#   'backers': 2294.0,
#   'country': 'US',
#   'usd pledged': 49456.5,
#   'usd_pledged_real': 457539.0},
#  {'_id': ObjectId('5fccbfdf247348e355265b45'),
#   'ID': 345567137,
#   'name': 'XenoShyft: Dreadmire',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-01-31',
#   'goal': 30000.0,
#   'launched': '2016-01-12 21:00:23',
#   'pledged': 383406.5,
#   'state': 'successful',
#   'backers': 4398.0,
#   'country': 'US',
#   'usd pledged': 383406.5,
#   'usd_pledged_real': 383406.5},
#  {'_id': ObjectId('5fccbfdf247348e355265cb1'),
#   'ID': 1887996020,
#   'name': 'NeoLucida XL',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-06-03',
#   'goal': 15000.0,
#   'launched': '2017-04-27 16:00:44',
#   'pledged': 332505.0,
#   'state': 'successful',
#   'backers': 5229.0,
#   'country': 'US',
#   'usd pledged': 130342.0,
#   'usd_pledged_real': 332505.0},
#  {'_id': ObjectId('5fccbfdf247348e355265ddf'),
#   'ID': 494497759,
#   'name': 'Lofree Poison: Nostalgic Powerful Wireless Speaker',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-09-01',
#   'goal': 10000.0,
#   'launched': '2017-08-02 17:03:48',
#   'pledged': 1456048.0,
#   'state': 'successful',
#   'backers': 2076.0,
#   'country': 'HK',
#   'usd pledged': 33538.39474242,
#   'usd_pledged_real': 186081.1777936816},
#  {'_id': ObjectId('5fccbfe0247348e355265e6a'),
#   'ID': 1301018404,
#   'name': 'LOAD the Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-06-08',
#   'goal': 30000.0,
#   'launched': '2016-05-19 20:00:28',
#   'pledged': 215471.52,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd pledged': 215471.52,
#   'usd_pledged_real': 215471.52},
#  {'_id': ObjectId('5fccbfe0247348e355265edd'),
#   'ID': 208387231,
#   'name': 'Battalion 1944 (PC/XB1/PS4)',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2016-03-03',
#   'goal': 100000.0,
#   'launched': '2016-02-02 13:14:44',
#   'pledged': 317281.67,
#   'state': 'successful',
#   'backers': 10096.0,
#   'country': 'GB',
#   'usd pledged': 452369.652297656,
#   'usd_pledged_real': 449203.85944048024},
#  {'_id': ObjectId('5fccbfe0247348e355265eee'),
#   'ID': 1902509544,
#   'name': 'EcoQube C- Your Window to Nature!',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-05-29',
#   'goal': 15000.0,
#   'launched': '2015-04-07 20:03:22',
#   'pledged': 375058.0,
#   'state': 'successful',
#   'backers': 5434.0,
#   'country': 'US',
#   'usd pledged': 375058.0,
#   'usd_pledged_real': 375058.0},
#  {'_id': ObjectId('5fccbfe0247348e35526604b'),
#   'ID': 2031859921,
#   'name': 'HICKIES 2.0 - The Evolution of Shoelaces',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-11-05',
#   'goal': 25000.0,
#   'launched': '2016-09-26 16:09:13',
#   'pledged': 580605.0,
#   'state': 'successful',
#   'backers': 13538.0,
#   'country': 'US',
#   'usd pledged': 11418.0,
#   'usd_pledged_real': 580605.0},
#  {'_id': ObjectId('5fccbfe0247348e3552660c6'),
#   'ID': 1627092657,
#   'name': 'Catalyst - Worldï¿½s Most Advanced Wireless Earbuds',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-11-04',
#   'goal': 25000.0,
#   'launched': '2016-09-13 15:29:23',
#   'pledged': 254819.0,
#   'state': 'successful',
#   'backers': 1439.0,
#   'country': 'US',
#   'usd pledged': 50159.0,
#   'usd_pledged_real': 254819.0},
#  {'_id': ObjectId('5fccbfe0247348e35526646f'),
#   'ID': 1769686041,
#   'name': 'POWERUP DART - App Controlled Paper Airplane. With Tricks.',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-10-18',
#   'goal': 25000.0,
#   'launched': '2017-09-12 15:30:47',
#   'pledged': 1678290.0,
#   'state': 'successful',
#   'backers': 24066.0,
#   'country': 'US',
#   'usd pledged': 849.0,
#   'usd_pledged_real': 1678290.0},
#  {'_id': ObjectId('5fccbfe0247348e3552664b6'),
#   'ID': 450224778,
#   'name': 'Venture : An automatic timepiece made with craftsman spirit',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-09-14',
#   'goal': 200000.0,
#   'launched': '2017-07-31 19:33:01',
#   'pledged': 202300.0,
#   'state': 'successful',
#   'backers': 75.0,
#   'country': 'HK',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 25881.81108708724},
#  {'_id': ObjectId('5fccbfe0247348e3552664c2'),
#   'ID': 804165301,
#   'name': 'TAKEDOWN',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-04-02',
#   'goal': 200000.0,
#   'launched': '2012-03-03 02:04:37',
#   'pledged': 221833.97,
#   'state': 'successful',
#   'backers': 5423.0,
#   'country': 'US',
#   'usd pledged': 221833.96875,
#   'usd_pledged_real': 221833.97},
#  {'_id': ObjectId('5fccbfe0247348e355266505'),
#   'ID': 1296381316,
#   'name': 'Danish Designer Wear - Made by Women in Prison',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'DKK',
#   'deadline': '2016-11-24',
#   'goal': 150000.0,
#   'launched': '2016-10-25 11:10:23',
#   'pledged': 351950.0,
#   'state': 'successful',
#   'backers': 277.0,
#   'country': 'DK',
#   'usd pledged': 23332.963709,
#   'usd_pledged_real': 50118.90691084117},
#  {'_id': ObjectId('5fccbfe1247348e35526676c'),
#   'ID': 1801275510,
#   'name': 'Zombicide: Green Horde',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-06-28',
#   'goal': 300000.0,
#   'launched': '2017-05-30 20:59:20',
#   'pledged': 5004494.58,
#   'state': 'successful',
#   'backers': 27235.0,
#   'country': 'US',
#   'usd pledged': 1242109.0,
#   'usd_pledged_real': 5004494.58},
#  {'_id': ObjectId('5fccbfe1247348e3552667e5'),
#   'ID': 1897028933,
#   'name': 'Revols - Premium Quick Custom-Fit Wireless Earphones',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-01-08',
#   'goal': 100000.0,
#   'launched': '2015-11-09 13:57:15',
#   'pledged': 2530756.27,
#   'state': 'successful',
#   'backers': 10569.0,
#   'country': 'US',
#   'usd pledged': 2530756.27,
#   'usd_pledged_real': 2530756.27},
#  {'_id': ObjectId('5fccbfe1247348e3552667fc'),
#   'ID': 221451068,
#   'name': "TAB | the world's most versatile convertible bag.",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-03-04',
#   'goal': 30000.0,
#   'launched': '2017-02-01 22:01:19',
#   'pledged': 344210.0,
#   'state': 'successful',
#   'backers': 2735.0,
#   'country': 'US',
#   'usd pledged': 27812.0,
#   'usd_pledged_real': 344210.0},
#  {'_id': ObjectId('5fccbfe1247348e355266847'),
#   'ID': 2049821432,
#   'name': 'Mi Bonsai | Le damos forma a tus finanzas',
#   'category': 'Apps',
#   'main_category': 'Technology',
#   'currency': 'MXN',
#   'deadline': '2017-02-15',
#   'goal': 50000.0,
#   'launched': '2017-01-16 01:04:43',
#   'pledged': 243270.0,
#   'state': 'successful',
#   'backers': 50.0,
#   'country': 'MX',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 11881.898993845853},
#  {'_id': ObjectId('5fccbfe1247348e3552668bf'),
#   'ID': 348146014,
#   'name': 'Artisan Dice Does Handcrafted Polyhedrals',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-05-01',
#   'goal': 9000.0,
#   'launched': '2013-03-12 20:08:35',
#   'pledged': 291920.97,
#   'state': 'successful',
#   'backers': 1174.0,
#   'country': 'US',
#   'usd pledged': 291920.97,
#   'usd_pledged_real': 291920.97},
#  {'_id': ObjectId('5fccbfe1247348e355266920'),
#   'ID': 2070324445,
#   'name': 'eon by UNLIMITED - Plug & Play Electric Skateboard',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-08-26',
#   'goal': 100000.0,
#   'launched': '2016-07-20 02:16:30',
#   'pledged': 315488.0,
#   'state': 'successful',
#   'backers': 604.0,
#   'country': 'ES',
#   'usd pledged': 33921.31911042,
#   'usd_pledged_real': 356185.78815453744},
#  {'_id': ObjectId('5fccbfe1247348e355266a5d'),
#   'ID': 1438557301,
#   'name': 'Sine Tempore',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-06-09',
#   'goal': 45000.0,
#   'launched': '2017-05-16 21:00:23',
#   'pledged': 654848.2,
#   'state': 'successful',
#   'backers': 4155.0,
#   'country': 'US',
#   'usd pledged': 95757.0,
#   'usd_pledged_real': 654848.2},
#  {'_id': ObjectId('5fccbfe1247348e355266aa0'),
#   'ID': 342886736,
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-08-30',
#   'goal': 50000.0,
#   'launched': '2014-07-08 10:14:37',
#   'pledged': 13285226.36,
#   'state': 'successful',
#   'backers': 62642.0,
#   'country': 'US',
#   'usd pledged': 13285226.0,
#   'usd_pledged_real': 13285226.36},
#  {'_id': ObjectId('5fccbfe1247348e355266aec'),
#   'ID': 664982962,
#   'name': 'Princess Awesome',
#   'category': 'Childrenswear',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-03-05',
#   'goal': 35000.0,
#   'launched': '2015-02-03 16:21:57',
#   'pledged': 215691.0,
#   'state': 'successful',
#   'backers': 3218.0,
#   'country': 'US',
#   'usd pledged': 215691.0,
#   'usd_pledged_real': 215691.0},
#  {'_id': ObjectId('5fccbfe1247348e355266b54'),
#   'ID': 1572015807,
#   'name': "Aeon's End: War Eternal",
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-04-21',
#   'goal': 30000.0,
#   'launched': '2017-03-21 16:15:57',
#   'pledged': 434703.0,
#   'state': 'successful',
#   'backers': 3890.0,
#   'country': 'US',
#   'usd pledged': 201364.0,
#   'usd_pledged_real': 434703.0},
#  {'_id': ObjectId('5fccbfe1247348e355266bde'),
#   'ID': 2096075781,
#   'name': 'Pathfinder: Kingmaker',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-07-12',
#   'goal': 500000.0,
#   'launched': '2017-06-06 16:32:25',
#   'pledged': 909057.32,
#   'state': 'successful',
#   'backers': 18351.0,
#   'country': 'US',
#   'usd pledged': 257647.0,
#   'usd_pledged_real': 909057.32},
#  {'_id': ObjectId('5fccbfe2247348e355266dd0'),
#   'ID': 1033978702,
#   'name': 'OUYA: A New Kind of Video Game Console',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-08-09',
#   'goal': 950000.0,
#   'launched': '2012-07-10 14:44:41',
#   'pledged': 8596474.58,
#   'state': 'successful',
#   'backers': 63416.0,
#   'country': 'US',
#   'usd pledged': 8596475.0,
#   'usd_pledged_real': 8596474.58},
#  {'_id': ObjectId('5fccbfe2247348e355266e5c'),
#   'ID': 117363944,
#   'name': 'Kniterate: The Digital Knitting Machine',
#   'category': 'Fabrication Tools',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-05-08',
#   'goal': 100000.0,
#   'launched': '2017-03-29 16:11:22',
#   'pledged': 636130.65,
#   'state': 'successful',
#   'backers': 488.0,
#   'country': 'US',
#   'usd pledged': 147428.0,
#   'usd_pledged_real': 636130.65},
#  {'_id': ObjectId('5fccbfe2247348e355266e84'),
#   'ID': 2058440271,
#   'name': 'Ambi Climate 2: A.I. Enhanced Air Conditioning Comfort',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-06-22',
#   'goal': 390000.0,
#   'launched': '2017-05-23 06:00:06',
#   'pledged': 1215905.0,
#   'state': 'successful',
#   'backers': 1016.0,
#   'country': 'HK',
#   'usd pledged': 78035.5,
#   'usd_pledged_real': 155889.25357060434},
#  {'_id': ObjectId('5fccbfe2247348e355266ee7'),
#   'ID': 1858985422,
#   'name': 'New Solar Technology to Build an Underground Park',
#   'category': 'Public Art',
#   'main_category': 'Art',
#   'currency': 'USD',
#   'deadline': '2015-07-09',
#   'goal': 200000.0,
#   'launched': '2015-06-09 18:22:24',
#   'pledged': 223506.08,
#   'state': 'successful',
#   'backers': 2564.0,
#   'country': 'US',
#   'usd pledged': 223506.08,
#   'usd_pledged_real': 223506.08},
#  {'_id': ObjectId('5fccbfe2247348e355266f60'),
#   'ID': 1004830984,
#   'name': 'Qi Aerista: The Ultimate Wi-Fi-Enabled Smart Tea Maker',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2016-12-15',
#   'goal': 600000.0,
#   'launched': '2016-11-15 16:51:13',
#   'pledged': 1343877.0,
#   'state': 'successful',
#   'backers': 1180.0,
#   'country': 'HK',
#   'usd pledged': 35693.04679080001,
#   'usd_pledged_real': 173126.48150056682},
#  {'_id': ObjectId('5fccbfe2247348e355266f89'),
#   'ID': 2030299056,
#   'name': 'The Empire - The Worldï¿½s Best Clubmaster Style Sunglasses',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-07-22',
#   'goal': 15000.0,
#   'launched': '2017-05-23 16:13:05',
#   'pledged': 491410.0,
#   'state': 'successful',
#   'backers': 2708.0,
#   'country': 'US',
#   'usd pledged': 63080.0,
#   'usd_pledged_real': 491410.0},
#  {'_id': ObjectId('5fccbfe2247348e355266fed'),
#   'ID': 709791525,
#   'name': 'The Mastery Journal: Master Productivity, Discipline & Focus',
#   'category': 'Nonfiction',
#   'main_category': 'Publishing',
#   'currency': 'USD',
#   'deadline': '2017-02-25',
#   'goal': 25000.0,
#   'launched': '2017-01-23 08:37:09',
#   'pledged': 280852.0,
#   'state': 'successful',
#   'backers': 3659.0,
#   'country': 'US',
#   'usd pledged': 76185.0,
#   'usd_pledged_real': 280852.0},
#  {'_id': ObjectId('5fccbfe2247348e35526706f'),
#   'ID': 642158610,
#   'name': 'JUISIR - Juicing Without the Cleaning',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'SGD',
#   'deadline': '2017-02-15',
#   'goal': 50000.0,
#   'launched': '2017-01-16 18:57:17',
#   'pledged': 579348.0,
#   'state': 'successful',
#   'backers': 915.0,
#   'country': 'SG',
#   'usd pledged': 194574.171875,
#   'usd_pledged_real': 408999.6470172961},
#  {'_id': ObjectId('5fccbfe2247348e35526709e'),
#   'ID': 1986736238,
#   'name': 'WarStages: The Gothic Cathedral',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-05',
#   'goal': 60000.0,
#   'launched': '2017-07-29 17:59:58',
#   'pledged': 202618.0,
#   'state': 'successful',
#   'backers': 681.0,
#   'country': 'US',
#   'usd pledged': 179062.0,
#   'usd_pledged_real': 202618.0},
#  {'_id': ObjectId('5fccbfe2247348e3552670ca'),
#   'ID': 367168138,
#   'name': 'The Opera di Firenze presents: Opera for Everybody',
#   'category': 'Theater',
#   'main_category': 'Theater',
#   'currency': 'EUR',
#   'deadline': '2016-07-15',
#   'goal': 300000.0,
#   'launched': '2016-05-31 14:03:04',
#   'pledged': 322202.0,
#   'state': 'successful',
#   'backers': 426.0,
#   'country': 'IT',
#   'usd pledged': 87567.08415625,
#   'usd_pledged_real': 358548.01197378227},
#  {'_id': ObjectId('5fccbfe2247348e355267100'),
#   'ID': 319307716,
#   'name': 'SmartHalo - Turn your bike into a smart bike',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2015-09-24',
#   'goal': 67000.0,
#   'launched': '2015-08-25 14:01:04',
#   'pledged': 538723.0,
#   'state': 'successful',
#   'backers': 3354.0,
#   'country': 'CA',
#   'usd pledged': 407250.67408603,
#   'usd_pledged_real': 404659.3555171637},
#  {'_id': ObjectId('5fccbfe2247348e35526721a'),
#   'ID': 623943939,
#   'name': 'Pretending to Grownup',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'CAD',
#   'deadline': '2016-10-31',
#   'goal': 6000.0,
#   'launched': '2016-10-03 16:06:02',
#   'pledged': 220266.74,
#   'state': 'successful',
#   'backers': 5988.0,
#   'country': 'CA',
#   'usd pledged': 23295.806640625,
#   'usd_pledged_real': 163974.34675798408},
#  {'_id': ObjectId('5fccbfe2247348e35526734a'),
#   'ID': 771637,
#   'name': "Loog Pro & Loog Mini: The ultimate beginners' guitars",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-05-27',
#   'goal': 30000.0,
#   'launched': '2017-04-24 14:02:41',
#   'pledged': 358286.0,
#   'state': 'successful',
#   'backers': 2391.0,
#   'country': 'US',
#   'usd pledged': 13740.0,
#   'usd_pledged_real': 358286.0},
#  {'_id': ObjectId('5fccbfe3247348e35526742d'),
#   'ID': 1136667722,
#   'name': 'The Etchr Art Satchel & Field Case',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'AUD',
#   'deadline': '2017-09-28',
#   'goal': 30000.0,
#   'launched': '2017-08-29 16:35:45',
#   'pledged': 429598.0,
#   'state': 'successful',
#   'backers': 1880.0,
#   'country': 'AU',
#   'usd pledged': 138466.15358544,
#   'usd_pledged_real': 336438.248884016},
#  {'_id': ObjectId('5fccbfe3247348e355267452'),
#   'ID': 1758139953,
#   'name': 'The Gamers: Hands of Fate',
#   'category': 'Narrative Film',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-09-08',
#   'goal': 320000.0,
#   'launched': '2012-07-18 04:57:56',
#   'pledged': 405916.78,
#   'state': 'successful',
#   'backers': 4311.0,
#   'country': 'US',
#   'usd pledged': 405916.78,
#   'usd_pledged_real': 405916.78},
#  {'_id': ObjectId('5fccbfe3247348e355267456'),
#   'ID': 464435132,
#   'name': 'The Diamond Hotend - Single nozzle multi-color 3D printing',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'DKK',
#   'deadline': '2015-05-01',
#   'goal': 150000.0,
#   'launched': '2015-04-01 09:34:20',
#   'pledged': 627209.0,
#   'state': 'successful',
#   'backers': 452.0,
#   'country': 'DK',
#   'usd pledged': 90945.296875,
#   'usd_pledged_real': 94293.0378700182},
#  {'_id': ObjectId('5fccbfe3247348e355267626'),
#   'ID': 745756933,
#   'name': 'MovieMask: Cinema experience anytime, anywhere',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'NOK',
#   'deadline': '2016-10-06',
#   'goal': 100000.0,
#   'launched': '2016-09-06 19:58:14',
#   'pledged': 286687.0,
#   'state': 'successful',
#   'backers': 369.0,
#   'country': 'NO',
#   'usd pledged': 12280.48046875,
#   'usd_pledged_real': 35481.50348395402},
#  {'_id': ObjectId('5fccbfe3247348e355267700'),
#   'ID': 543976493,
#   'name': 'Solid Titanium Pen + Stylus',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-08-14',
#   'goal': 30000.0,
#   'launched': '2012-06-15 23:54:42',
#   'pledged': 313371.01,
#   'state': 'successful',
#   'backers': 3258.0,
#   'country': 'US',
#   'usd pledged': 313371.0,
#   'usd_pledged_real': 313371.01},
#  {'_id': ObjectId('5fccbfe3247348e355267780'),
#   'ID': 1732819832,
#   'name': 'HiddenRadio2 Bluetooth MultiSpeaker',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-02-05',
#   'goal': 90000.0,
#   'launched': '2013-12-07 23:31:15',
#   'pledged': 720919.75,
#   'state': 'successful',
#   'backers': 3642.0,
#   'country': 'US',
#   'usd pledged': 720919.75,
#   'usd_pledged_real': 720919.75},
#  {'_id': ObjectId('5fccbfe3247348e355267798'),
#   'ID': 803679431,
#   'name': 'BSCSMX- B?sicos de M?xico',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'MXN',
#   'deadline': '2017-09-13',
#   'goal': 185000.0,
#   'launched': '2017-08-14 21:58:30',
#   'pledged': 257745.0,
#   'state': 'successful',
#   'backers': 205.0,
#   'country': 'MX',
#   'usd pledged': 3697.6993408,
#   'usd_pledged_real': 14588.238623500114},
#  {'_id': ObjectId('5fccbfe3247348e3552677cd'),
#   'ID': 960928351,
#   'name': "Helixï¿½ - The World's Best Folding Bike",
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CAD',
#   'deadline': '2015-10-01',
#   'goal': 120000.0,
#   'launched': '2015-09-01 16:20:57',
#   'pledged': 2262621.24,
#   'state': 'successful',
#   'backers': 1069.0,
#   'country': 'CA',
#   'usd pledged': 1709748.42768568,
#   'usd_pledged_real': 1709057.5118966692},
#  {'_id': ObjectId('5fccbfe3247348e355267893'),
#   'ID': 474144967,
#   'name': 'Crowfall - Throne War PC MMO',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-03-26',
#   'goal': 800000.0,
#   'launched': '2015-02-24 14:00:26',
#   'pledged': 1766204.58,
#   'state': 'successful',
#   'backers': 16936.0,
#   'country': 'US',
#   'usd pledged': 1766204.58,
#   'usd_pledged_real': 1766204.58},
#  {'_id': ObjectId('5fccbfe3247348e355267b23'),
#   'ID': 1169904340,
#   'name': 'Plugfones - Bluetooth Earplug Headphones - Music Calls Quiet',
#   'category': 'Sound',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-05-13',
#   'goal': 35000.0,
#   'launched': '2016-03-29 11:46:32',
#   'pledged': 427247.5,
#   'state': 'successful',
#   'backers': 4851.0,
#   'country': 'US',
#   'usd pledged': 427247.5,
#   'usd_pledged_real': 427247.5},
#  {'_id': ObjectId('5fccbfe4247348e355267c78'),
#   'ID': 133188892,
#   'name': 'Sub Terra: a Cooperative Survival Horror Game for 1-6 Cavers',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-02-17',
#   'goal': 16500.0,
#   'launched': '2017-01-10 09:00:08',
#   'pledged': 368256.65,
#   'state': 'successful',
#   'backers': 6626.0,
#   'country': 'GB',
#   'usd pledged': 78392.59375,
#   'usd_pledged_real': 457529.88023059344},
#  {'_id': ObjectId('5fccbfe4247348e355267cf4'),
#   'ID': 1127031239,
#   'name': 'TAKTIK: Premium Protection System for the iPhone',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-07-21',
#   'goal': 150000.0,
#   'launched': '2012-06-21 16:43:39',
#   'pledged': 680568.09,
#   'state': 'successful',
#   'backers': 4597.0,
#   'country': 'US',
#   'usd pledged': 680568.09,
#   'usd_pledged_real': 680568.09},
#  {'_id': ObjectId('5fccbfe4247348e355267d2c'),
#   'ID': 1339618489,
#   'name': 'Hie Diaper Bag: Your New Best Friend',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-07-15',
#   'goal': 60000.0,
#   'launched': '2017-06-12 17:54:56',
#   'pledged': 395666.0,
#   'state': 'successful',
#   'backers': 1882.0,
#   'country': 'US',
#   'usd pledged': 259582.0,
#   'usd_pledged_real': 395666.0},
#  {'_id': ObjectId('5fccbfe4247348e355267d2e'),
#   'ID': 1260031333,
#   'name': 'Terremoto, a unique Pan-American art magazine',
#   'category': 'Periodicals',
#   'main_category': 'Publishing',
#   'currency': 'MXN',
#   'deadline': '2017-06-15',
#   'goal': 400000.0,
#   'launched': '2017-05-15 18:26:34',
#   'pledged': 441683.19,
#   'state': 'successful',
#   'backers': 313.0,
#   'country': 'MX',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 24551.59477487493},
#  {'_id': ObjectId('5fccbfe4247348e355267d65'),
#   'ID': 726158562,
#   'name': 'The Ultimate Sleep Travel Solution - NodPod',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-09-09',
#   'goal': 20000.0,
#   'launched': '2016-07-26 16:59:51',
#   'pledged': 307274.0,
#   'state': 'successful',
#   'backers': 7280.0,
#   'country': 'US',
#   'usd pledged': 485.0,
#   'usd_pledged_real': 307274.0},
#  {'_id': ObjectId('5fccbfe4247348e355267d96'),
#   'ID': 1992399244,
#   'name': 'Skreens: Everything you want on one display.',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-11-01',
#   'goal': 25000.0,
#   'launched': '2015-09-22 22:40:27',
#   'pledged': 471909.0,
#   'state': 'successful',
#   'backers': 1263.0,
#   'country': 'US',
#   'usd pledged': 471909.0,
#   'usd_pledged_real': 471909.0},
#  {'_id': ObjectId('5fccbfe4247348e355267df0'),
#   'ID': 1279559829,
#   'name': 'Forbidden Lands - Retro Open-World Survival Fantasy RPG',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'SEK',
#   'deadline': '2017-10-12',
#   'goal': 100000.0,
#   'launched': '2017-09-21 13:56:38',
#   'pledged': 2828267.0,
#   'state': 'successful',
#   'backers': 3399.0,
#   'country': 'SE',
#   'usd pledged': 134118.27571618,
#   'usd_pledged_real': 347756.27389983897},
#  {'_id': ObjectId('5fccbfe4247348e355267ff7'),
#   'ID': 355636922,
#   'name': 'MAGBELT - A magnetic belt that fits perfectly to your waist.',
#   'category': 'Accessories',
#   'main_category': 'Fashion',
#   'currency': 'USD',
#   'deadline': '2015-07-19',
#   'goal': 7500.0,
#   'launched': '2015-06-03 12:06:42',
#   'pledged': 583544.56,
#   'state': 'successful',
#   'backers': 9707.0,
#   'country': 'US',
#   'usd pledged': 583544.56,
#   'usd_pledged_real': 583544.56},
#  {'_id': ObjectId('5fccbfe4247348e355268090'),
#   'ID': 430897661,
#   'name': 'Lifepack: Solar Powered & Anti-Theft Backpack',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-04-28',
#   'goal': 20000.0,
#   'launched': '2016-02-29 15:01:04',
#   'pledged': 613917.5,
#   'state': 'successful',
#   'backers': 3705.0,
#   'country': 'US',
#   'usd pledged': 613917.5,
#   'usd_pledged_real': 613917.5},
#  {'_id': ObjectId('5fccbfe4247348e3552680ec'),
#   'ID': 1457046836,
#   'name': 'The Bero | A Smart Lamp with App and Sensor.',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-05-22',
#   'goal': 350000.0,
#   'launched': '2017-04-07 18:29:23',
#   'pledged': 343154.0,
#   'state': 'suspended',
#   'backers': 520.0,
#   'country': 'HK',
#   'usd pledged': 7793.105136300002,
#   'usd_pledged_real': 44034.18496323576},
#  {'_id': ObjectId('5fccbfe4247348e3552680ef'),
#   'ID': 496621448,
#   'name': 'CLANNAD Official English Release',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2015-01-09',
#   'goal': 140000.0,
#   'launched': '2014-11-10 19:48:28',
#   'pledged': 541161.6,
#   'state': 'successful',
#   'backers': 5819.0,
#   'country': 'US',
#   'usd pledged': 541161.6,
#   'usd_pledged_real': 541161.6},
#  {'_id': ObjectId('5fccbfe4247348e35526810b'),
#   'ID': 460079166,
#   'name': 'movE - urban mobility reimagined',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'DKK',
#   'deadline': '2017-10-20',
#   'goal': 190000.0,
#   'launched': '2017-09-20 19:07:24',
#   'pledged': 208722.0,
#   'state': 'successful',
#   'backers': 25.0,
#   'country': 'DK',
#   'usd pledged': 2299.65456,
#   'usd_pledged_real': 33137.31404893073},
#  {'_id': ObjectId('5fccbfe5247348e355268326'),
#   'ID': 496736487,
#   'name': 'HyperDriveï¿½ Compact Thunderbolt 3 USB-C Hub for MacBook Pro',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-01-17',
#   'goal': 100000.0,
#   'launched': '2016-12-05 17:00:05',
#   'pledged': 1842141.69,
#   'state': 'successful',
#   'backers': 20680.0,
#   'country': 'US',
#   'usd pledged': 159015.0,
#   'usd_pledged_real': 1842141.69},
#  {'_id': ObjectId('5fccbfe5247348e3552683f6'),
#   'ID': 800563986,
#   'name': 'The Floyd Leg',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2014-02-08',
#   'goal': 18000.0,
#   'launched': '2014-01-07 17:43:45',
#   'pledged': 256273.0,
#   'state': 'successful',
#   'backers': 1395.0,
#   'country': 'US',
#   'usd pledged': 256273.0,
#   'usd_pledged_real': 256273.0},
#  {'_id': ObjectId('5fccbfe5247348e3552688cb'),
#   'ID': 1582200376,
#   'name': 'ARMBOT: Affordable Robotic Arm 3D Printer running Windows',
#   'category': '3D Printing',
#   'main_category': 'Technology',
#   'currency': 'HKD',
#   'deadline': '2017-01-26',
#   'goal': 150000.0,
#   'launched': '2016-12-07 01:42:53',
#   'pledged': 231036.0,
#   'state': 'successful',
#   'backers': 68.0,
#   'country': 'HK',
#   'usd pledged': 4815.885096,
#   'usd_pledged_real': 29776.9013648842},
#  {'_id': ObjectId('5fccbfe5247348e3552689d7'),
#   'ID': 594397687,
#   'name': 'Hackaball - A computer you can throw',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-04-03',
#   'goal': 100000.0,
#   'launched': '2015-03-03 14:37:06',
#   'pledged': 241122.0,
#   'state': 'successful',
#   'backers': 2312.0,
#   'country': 'US',
#   'usd pledged': 241122.0,
#   'usd_pledged_real': 241122.0},
#  {'_id': ObjectId('5fccbfe5247348e355268a2c'),
#   'ID': 1318522640,
#   'name': 'Ekster Wallets: The next Generation Wallet',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-01-29',
#   'goal': 15000.0,
#   'launched': '2015-12-15 08:31:39',
#   'pledged': 331946.6,
#   'state': 'successful',
#   'backers': 3009.0,
#   'country': 'NL',
#   'usd pledged': 363819.75,
#   'usd_pledged_real': 362486.0496860497},
#  {'_id': ObjectId('5fccbfe6247348e355268a8c'),
#   'ID': 862418695,
#   'name': 'unicoï¿½',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'EUR',
#   'deadline': '2017-12-09',
#   'goal': 75000.0,
#   'launched': '2017-10-10 12:29:49',
#   'pledged': 897071.0,
#   'state': 'canceled',
#   'backers': 6934.0,
#   'country': 'IT',
#   'usd pledged': 474.15057616,
#   'usd_pledged_real': 1059078.1908551056},
#  {'_id': ObjectId('5fccbfe6247348e355268af7'),
#   'ID': 798069470,
#   'name': 'iControlPad 2 - The open source controller',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2012-10-13',
#   'goal': 150000.0,
#   'launched': '2012-09-13 15:33:15',
#   'pledged': 209100.8,
#   'state': 'successful',
#   'backers': 2168.0,
#   'country': 'US',
#   'usd pledged': 209100.8,
#   'usd_pledged_real': 209100.8},
#  {'_id': ObjectId('5fccbfe6247348e355268b59'),
#   'ID': 1078982332,
#   'name': 'BRIDEGROOM - An American Love Story',
#   'category': 'Documentary',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2012-07-20',
#   'goal': 300000.0,
#   'launched': '2012-06-20 01:00:28',
#   'pledged': 384375.87,
#   'state': 'successful',
#   'backers': 6508.0,
#   'country': 'US',
#   'usd pledged': 384375.87,
#   'usd_pledged_real': 384375.87},
#  {'_id': ObjectId('5fccbfe6247348e355268b8e'),
#   'ID': 1572939557,
#   'name': "Space Case 1 - The World's Most Advanced Smart Suitcase",
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-07-16',
#   'goal': 50000.0,
#   'launched': '2015-06-01 16:02:29',
#   'pledged': 920122.0,
#   'state': 'successful',
#   'backers': 1976.0,
#   'country': 'US',
#   'usd pledged': 920122.0,
#   'usd_pledged_real': 920122.0},
#  {'_id': ObjectId('5fccbfe6247348e355268cbf'),
#   'ID': 433143026,
#   'name': 'Mizu | The Future of Towels',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-12-04',
#   'goal': 10000.0,
#   'launched': '2017-10-30 15:39:47',
#   'pledged': 264285.0,
#   'state': 'successful',
#   'backers': 2080.0,
#   'country': 'US',
#   'usd pledged': 24198.0,
#   'usd_pledged_real': 264285.0},
#  {'_id': ObjectId('5fccbfe6247348e355268ee8'),
#   'ID': 1854390555,
#   'name': 'Buhel Tech Sunglasses + Headphones: No Earphones Or Wires!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-03-14',
#   'goal': 80000.0,
#   'launched': '2015-02-02 17:08:02',
#   'pledged': 416376.0,
#   'state': 'successful',
#   'backers': 2283.0,
#   'country': 'US',
#   'usd pledged': 416376.0,
#   'usd_pledged_real': 416376.0},
#  {'_id': ObjectId('5fccbfe6247348e355268f05'),
#   'ID': 1751772364,
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-01-23',
#   'goal': 250000.0,
#   'launched': '2014-12-10 18:58:08',
#   'pledged': 342471.0,
#   'state': 'successful',
#   'backers': 1096.0,
#   'country': 'US',
#   'usd pledged': 342471.0,
#   'usd_pledged_real': 342471.0},
#  {'_id': ObjectId('5fccbfe6247348e355268f2b'),
#   'ID': 1184410949,
#   'name': 'NFC Ring',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'GBP',
#   'deadline': '2013-08-19',
# ...
#   'launched': '2017-10-25 06:19:34',
#   'pledged': 319052.0,
#   'state': 'successful',
#   'backers': 2175.0,
#   'country': 'US',
#   'usd pledged': 56030.0,
#   'usd_pledged_real': 319052.0},
#  {'_id': ObjectId('5fccbfee247348e35526c1e1'),
#   'ID': 729484586,
#   'name': 'Time of Legends: Joan of Arc',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-11-10',
#   'goal': 100000.0,
#   'launched': '2017-10-10 21:00:05',
#   'pledged': 2152285.02,
#   'state': 'successful',
#   'backers': 9987.0,
#   'country': 'US',
#   'usd pledged': 355231.0,
#   'usd_pledged_real': 2152285.02},
#  {'_id': ObjectId('5fccbfee247348e35526c1e8'),
#   'ID': 318711594,
#   'name': 'Minimalist Bags Without The Luxury Markup',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-04-25',
#   'goal': 400000.0,
#   'launched': '2017-03-16 13:43:15',
#   'pledged': 2990330.0,
#   'state': 'successful',
#   'backers': 1168.0,
#   'country': 'HK',
#   'usd pledged': 99005.33524696,
#   'usd_pledged_real': 384504.5068213087},
#  {'_id': ObjectId('5fccbfee247348e35526c20a'),
#   'ID': 1218533935,
#   'name': '3Dsimo mini - Make your vision come true',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-10-12',
#   'goal': 35000.0,
#   'launched': '2015-08-28 13:40:19',
#   'pledged': 229958.0,
#   'state': 'successful',
#   'backers': 1822.0,
#   'country': 'US',
#   'usd pledged': 229958.0,
#   'usd_pledged_real': 229958.0},
#  {'_id': ObjectId('5fccbfee247348e35526c220'),
#   'ID': 245259349,
#   'name': 'HAND Stylus',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2012-06-17',
#   'goal': 25000.0,
#   'launched': '2012-05-03 06:51:12',
#   'pledged': 313490.67,
#   'state': 'successful',
#   'backers': 7511.0,
#   'country': 'US',
#   'usd pledged': 313490.67,
#   'usd_pledged_real': 313490.67},
#  {'_id': ObjectId('5fccbfee247348e35526c24c'),
#   'ID': 1616845470,
#   'name': 'Woobo: A Smart Companion for Curious Kids',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-10-21',
#   'goal': 50000.0,
#   'launched': '2017-09-21 16:47:51',
#   'pledged': 221642.0,
#   'state': 'successful',
#   'backers': 1425.0,
#   'country': 'US',
#   'usd pledged': 83235.0,
#   'usd_pledged_real': 221642.0},
#  {'_id': ObjectId('5fccbfee247348e35526c284'),
#   'ID': 815224727,
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem',
#   'category': 'Restaurants',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2014-01-07',
#   'goal': 250000.0,
#   'launched': '2013-12-04 18:56:58',
#   'pledged': 310225.01,
#   'state': 'successful',
#   'backers': 2026.0,
#   'country': 'US',
#   'usd pledged': 310225.01,
#   'usd_pledged_real': 310225.01},
#  {'_id': ObjectId('5fccbfee247348e35526c29f'),
#   'ID': 2137602357,
#   'name': 'ZUNGLE : Wear the Beats',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2016-07-16',
#   'goal': 50000.0,
#   'launched': '2016-06-16 16:41:54',
#   'pledged': 1947035.0,
#   'state': 'successful',
#   'backers': 11349.0,
#   'country': 'US',
#   'usd pledged': 207044.0,
#   'usd_pledged_real': 1947035.0},
#  {'_id': ObjectId('5fccbfef247348e35526c4c6'),
#   'ID': 1449637502,
#   'name': 'ALCHEMA: Turn Fruit into Personalized Craft Cider',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-09-09',
#   'goal': 80000.0,
#   'launched': '2016-07-26 15:00:10',
#   'pledged': 344231.6,
#   'state': 'successful',
#   'backers': 899.0,
#   'country': 'US',
#   'usd pledged': 11416.0,
#   'usd_pledged_real': 344231.6},
#  {'_id': ObjectId('5fccbfef247348e35526c4df'),
#   'ID': 489602255,
#   'name': 'Acteon Compression Packing Cubes',
#   'category': 'Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2017-03-18',
#   'goal': 20000.0,
#   'launched': '2017-02-15 16:29:40',
#   'pledged': 744628.0,
#   'state': 'successful',
#   'backers': 11661.0,
#   'country': 'US',
#   'usd pledged': 21654.0,
#   'usd_pledged_real': 744628.0},
#  {'_id': ObjectId('5fccbfef247348e35526c517'),
#   'ID': 1280589435,
#   'name': 'New Studio Album from Toad the Wet Sprocket!',
#   'category': 'Rock',
#   'main_category': 'Music',
#   'currency': 'USD',
#   'deadline': '2013-08-04',
#   'goal': 50000.0,
#   'launched': '2013-06-05 23:36:52',
#   'pledged': 264762.72,
#   'state': 'successful',
#   'backers': 6304.0,
#   'country': 'US',
#   'usd pledged': 264762.72,
#   'usd_pledged_real': 264762.72},
#  {'_id': ObjectId('5fccbfef247348e35526c527'),
#   'ID': 1304573807,
#   'name': 'Resident Evilï¿½ 2 - The Board Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'GBP',
#   'deadline': '2017-10-23',
#   'goal': 150000.0,
#   'launched': '2017-09-25 21:00:00',
#   'pledged': 800561.0,
#   'state': 'successful',
#   'backers': 7583.0,
#   'country': 'GB',
#   'usd pledged': 123812.23546197,
#   'usd_pledged_real': 1048197.7086743044},
#  {'_id': ObjectId('5fccbfef247348e35526c539'),
#   'ID': 1310046506,
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!',
#   'category': 'Wearables',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2015-04-18',
#   'goal': 30000.0,
#   'launched': '2015-03-18 23:35:57',
#   'pledged': 216436.0,
#   'state': 'successful',
#   'backers': 5538.0,
#   'country': 'US',
#   'usd pledged': 216436.0,
#   'usd_pledged_real': 216436.0},
#  {'_id': ObjectId('5fccbfef247348e35526c561'),
#   'ID': 249618800,
#   'name': 'High-performance outerwear at a revolutionary price',
#   'category': 'Apparel',
#   'main_category': 'Fashion',
#   'currency': 'EUR',
#   'deadline': '2017-04-08',
#   'goal': 25000.0,
#   'launched': '2017-02-27 17:52:18',
#   'pledged': 237227.0,
#   'state': 'successful',
#   'backers': 692.0,
#   'country': 'NL',
#   'usd pledged': 35475.28520076,
#   'usd_pledged_real': 252173.312214982},
#  {'_id': ObjectId('5fccbfef247348e35526c5f6'),
#   'ID': 1730867615,
#   'name': 'Krosmaster Arena Anime Miniatures Game - Frigost Expansion',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2013-12-16',
#   'goal': 25000.0,
#   'launched': '2013-11-16 00:59:07',
#   'pledged': 361764.01,
#   'state': 'successful',
#   'backers': 1362.0,
#   'country': 'US',
#   'usd pledged': 361764.0,
#   'usd_pledged_real': 361764.01},
#  {'_id': ObjectId('5fccbfef247348e35526c637'),
#   'ID': 1599168323,
#   'name': 'I DRAW COMICS Sketchbook & Reference Guide',
#   'category': 'Comics',
#   'main_category': 'Comics',
#   'currency': 'USD',
#   'deadline': '2012-09-19',
#   'goal': 10000.0,
#   'launched': '2012-08-20 06:01:16',
#   'pledged': 245870.22,
#   'state': 'successful',
#   'backers': 6466.0,
#   'country': 'US',
#   'usd pledged': 245870.21875,
#   'usd_pledged_real': 245870.22},
#  {'_id': ObjectId('5fccbfef247348e35526c670'),
#   'ID': 1099147645,
#   'name': 'Belos - Swedish self-winding watches',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'SEK',
#   'deadline': '2016-06-03',
#   'goal': 200000.0,
#   'launched': '2016-05-04 14:56:31',
#   'pledged': 270616.0,
#   'state': 'successful',
#   'backers': 139.0,
#   'country': 'SE',
#   'usd pledged': 33962.66521312,
#   'usd_pledged_real': 32594.912314511465},
#  {'_id': ObjectId('5fccbfef247348e35526c718'),
#   'ID': 1719674104,
#   'name': 'Petcube ï¿½ stay closer to your pet',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-05',
#   'goal': 100000.0,
#   'launched': '2013-09-24 16:57:01',
#   'pledged': 251225.99,
#   'state': 'successful',
#   'backers': 1758.0,
#   'country': 'US',
#   'usd pledged': 251225.99,
#   'usd_pledged_real': 251225.99},
#  {'_id': ObjectId('5fccbfef247348e35526c916'),
#   'ID': 653671188,
#   'name': 'The Pocket TV: Makes any TV a Smart TV',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2012-07-09',
#   'goal': 100000.0,
#   'launched': '2012-05-30 18:00:22',
#   'pledged': 501321.12,
#   'state': 'successful',
#   'backers': 3164.0,
#   'country': 'US',
#   'usd pledged': 501321.12,
#   'usd_pledged_real': 501321.12},
#  {'_id': ObjectId('5fccbfef247348e35526c970'),
#   'ID': 170629968,
#   'name': 'The Walking Dead No Sanctuary',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2016-08-02',
#   'goal': 250000.0,
#   'launched': '2016-07-12 19:00:27',
#   'pledged': 433644.0,
#   'state': 'successful',
#   'backers': 3086.0,
#   'country': 'US',
#   'usd pledged': 209993.0,
#   'usd_pledged_real': 433644.0},
#  {'_id': ObjectId('5fccbfef247348e35526c9a9'),
#   'ID': 1875594564,
#   'name': 'Holus: The Interactive Tabletop Holographic Display',
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2015-07-10',
#   'goal': 50000.0,
#   'launched': '2015-06-10 14:59:52',
#   'pledged': 297790.0,
#   'state': 'successful',
#   'backers': 496.0,
#   'country': 'CA',
#   'usd pledged': 239996.265625,
#   'usd_pledged_real': 234369.58917047066},
#  {'_id': ObjectId('5fccbfef247348e35526c9b9'),
#   'ID': 731137767,
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2013-11-18',
#   'goal': 25000.0,
#   'launched': '2013-10-17 02:51:37',
#   'pledged': 211027.66,
#   'state': 'successful',
#   'backers': 1558.0,
#   'country': 'US',
#   'usd pledged': 211027.66,
#   'usd_pledged_real': 211027.66},
#  {'_id': ObjectId('5fccbfef247348e35526cb4b'),
#   'ID': 1101976535,
#   'name': 'CUERPOS DE SAL',
#   'category': 'Drama',
#   'main_category': 'Film & Video',
#   'currency': 'MXN',
#   'deadline': '2017-12-29',
#   'goal': 200000.0,
#   'launched': '2017-11-29 01:47:36',
#   'pledged': 205289.0,
#   'state': 'successful',
#   'backers': 60.0,
#   'country': 'MX',
#   'usd pledged': 247.72936600000003,
#   'usd_pledged_real': 10405.443762988494},
#  {'_id': ObjectId('5fccbfef247348e35526cb92'),
#   'ID': 1922499586,
#   'name': 'War Room: A Larry Harris Game',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-12-09',
#   'goal': 150000.0,
#   'launched': '2017-10-30 13:59:59',
#   'pledged': 402055.0,
#   'state': 'successful',
#   'backers': 1753.0,
#   'country': 'US',
#   'usd pledged': 56964.0,
#   'usd_pledged_real': 402055.0},
#  {'_id': ObjectId('5fccbff0247348e35526ccad'),
#   'ID': 170672682,
#   'name': 'The Field Skillet: Lighter, Smoother Cast Iron',
#   'category': 'Food',
#   'main_category': 'Food',
#   'currency': 'USD',
#   'deadline': '2016-04-07',
#   'goal': 30000.0,
#   'launched': '2016-03-07 02:25:16',
#   'pledged': 1633361.53,
#   'state': 'successful',
#   'backers': 12553.0,
#   'country': 'US',
#   'usd pledged': 1633361.53,
#   'usd_pledged_real': 1633361.53},
#  {'_id': ObjectId('5fccbff0247348e35526cdf1'),
#   'ID': 2111201788,
#   'name': 'Expect the Unexpected. digiFilmï¿½ Camera by YASHICA',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'HKD',
#   'deadline': '2017-11-19',
#   'goal': 800000.0,
#   'launched': '2017-10-10 12:52:25',
#   'pledged': 10035296.0,
#   'state': 'successful',
#   'backers': 6935.0,
#   'country': 'HK',
#   'usd pledged': 4788.64208984375,
#   'usd_pledged_real': 1285142.981546224},
#  {'_id': ObjectId('5fccbff0247348e35526ce13'),
#   'ID': 1523269305,
#   'name': 'Dragonï¿½s Lair: The Movie (Canceled)',
#   'category': 'Film & Video',
#   'main_category': 'Film & Video',
#   'currency': 'USD',
#   'deadline': '2015-11-26',
#   'goal': 550000.0,
#   'launched': '2015-10-26 17:00:47',
#   'pledged': 241579.82,
#   'state': 'canceled',
#   'backers': 2954.0,
#   'country': 'US',
#   'usd pledged': 241579.82,
#   'usd_pledged_real': 241579.82},
#  {'_id': ObjectId('5fccbff0247348e35526cedf'),
#   'ID': 11280589,
#   'name': 'Jelly, The Smallest 4G Smartphone',
#   'category': 'Gadgets',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-06-06',
#   'goal': 30000.0,
#   'launched': '2017-05-02 16:59:09',
#   'pledged': 1251380.03,
#   'state': 'successful',
#   'backers': 10964.0,
#   'country': 'US',
#   'usd pledged': 67514.0,
#   'usd_pledged_real': 1251380.03},
#  {'_id': ObjectId('5fccbff0247348e35526d054'),
#   'ID': 1139702906,
#   'name': 'Dreamcade Replay - One Console To Rule Them All',
#   'category': 'Gaming Hardware',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-08-17',
#   'goal': 30000.0,
#   'launched': '2017-07-17 02:12:15',
#   'pledged': 228854.01,
#   'state': 'successful',
#   'backers': 1642.0,
#   'country': 'US',
#   'usd pledged': 12098.0,
#   'usd_pledged_real': 228854.01},
#  {'_id': ObjectId('5fccbff0247348e35526d06c'),
#   'ID': 602097857,
#   'name': 'DWISS M2 Automatic Swiss Watch with Innovative Time Reading',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'CHF',
#   'deadline': '2016-08-12',
#   'goal': 30000.0,
#   'launched': '2016-07-04 17:59:43',
#   'pledged': 407837.0,
#   'state': 'successful',
#   'backers': 479.0,
#   'country': 'CH',
#   'usd pledged': 109147.66433598,
#   'usd_pledged_real': 417951.42447222787},
#  {'_id': ObjectId('5fccbff0247348e35526d0f3'),
#   'ID': 861404368,
#   'name': 'Polar Ice Tray: The Perfect Ice for the Perfect Drink!',
#   'category': 'Product Design',
#   'main_category': 'Design',
#   'currency': 'USD',
#   'deadline': '2015-07-25',
#   'goal': 10000.0,
#   'launched': '2015-05-26 16:59:06',
#   'pledged': 291356.0,
#   'state': 'successful',
#   'backers': 4185.0,
#   'country': 'US',
#   'usd pledged': 291356.0,
#   'usd_pledged_real': 291356.0},
#  {'_id': ObjectId('5fccbff0247348e35526d10f'),
#   'ID': 260174130,
#   'name': 'Empires of the Void II',
#   'category': 'Tabletop Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2017-03-25',
#   'goal': 25000.0,
#   'launched': '2017-02-27 16:57:10',
#   'pledged': 275400.0,
#   'state': 'successful',
#   'backers': 4022.0,
#   'country': 'US',
#   'usd pledged': 124261.0,
#   'usd_pledged_real': 275400.0},
#  {'_id': ObjectId('5fccbff1247348e35526d19c'),
#   'ID': 1471094223,
#   'name': 'Fleye - Your Personal Flying Robot',
#   'category': 'Flight',
#   'main_category': 'Technology',
#   'currency': 'EUR',
#   'deadline': '2016-01-15',
#   'goal': 175000.0,
#   'launched': '2015-12-03 13:59:31',
#   'pledged': 314080.0,
#   'state': 'successful',
#   'backers': 717.0,
#   'country': 'BE',
#   'usd pledged': 333529.4375,
#   'usd_pledged_real': 342788.5402455661},
#  {'_id': ObjectId('5fccbff1247348e35526d258'),
#   'ID': 804968145,
#   'name': 'Cubiio: The Most Compact Laser Engraver',
#   'category': 'Fabrication Tools',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2017-09-20',
#   'goal': 25000.0,
#   'launched': '2017-08-15 16:02:38',
#   'pledged': 1373680.11,
#   'state': 'successful',
#   'backers': 3432.0,
#   'country': 'US',
#   'usd pledged': 97113.0,
#   'usd_pledged_real': 1373680.11},
#  {'_id': ObjectId('5fccbff1247348e35526d437'),
#   'ID': 545788185,
#   'name': "World's First And Only Complete Weather Camera System",
#   'category': 'Technology',
#   'main_category': 'Technology',
#   'currency': 'USD',
#   'deadline': '2016-08-30',
#   'goal': 80000.0,
#   'launched': '2016-07-20 22:37:35',
#   'pledged': 680826.0,
#   'state': 'successful',
#   'backers': 2966.0,
#   'country': 'US',
#   'usd pledged': 0.0,
#   'usd_pledged_real': 680826.0},
#  {'_id': ObjectId('5fccbff1247348e35526d4cf'),
#   'ID': 851709096,
#   'name': 'ALL Controller | Universal & Fully Customizable',
#   'category': 'Hardware',
#   'main_category': 'Technology',
#   'currency': 'CAD',
#   'deadline': '2017-09-15',
#   'goal': 75000.0,
#   'launched': '2017-08-01 14:58:45',
#   'pledged': 232026.0,
#   'state': 'successful',
#   'backers': 1734.0,
#   'country': 'CA',
#   'usd pledged': 9991.31188534,
#   'usd_pledged_real': 191172.44788662766},
#  {'_id': ObjectId('5fccbff1247348e35526d617'),
#   'ID': 1911111579,
#   'name': 'Two Guys SpaceVenture - by the creators of Space Quest',
#   'category': 'Video Games',
#   'main_category': 'Games',
#   'currency': 'USD',
#   'deadline': '2012-06-12',
#   'goal': 500000.0,
#   'launched': '2012-05-08 19:27:38',
#   'pledged': 539767.64,
#   'state': 'successful',
#   'backers': 10809.0,
#   'country': 'US',
#   'usd pledged': 539767.64,
#   'usd_pledged_real': 539767.64}]

# %%
cur=collection.find({"pledged":{ "$gte" :  200000}})
len(list(cur))
# Out:
# 219

# %% [markdown]
# ## Question 6

# %% [markdown]
# collection.find({"name" : {"$regex": ".*Sport.*"}}).count(True)

# %%
cur=collection.find({"name" : {"$regex": ".*Sport.*"}})
len(list(cur))
# Out:
# 76
